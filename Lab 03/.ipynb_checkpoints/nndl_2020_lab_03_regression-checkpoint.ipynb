# %% [markdown]
# #NEURAL NETWORKS AND DEEP LEARNING
# > M.Sc. ICT FOR LIFE AND HEALTH
# >
# > Department of Information Engineering
#
# > M.Sc. COMPUTER ENGINEERING
# >
# > Department of Information Engineering
#
# > M.Sc. AUTOMATION ENGINEERING
# >
# > Department of Information Engineering
#
# > M.Sc. PHYSICS OF DATA
# >
# > Department of Physics and Astronomy
#
# > M.Sc. COGNITIVE NEUROSCIENCE AND CLINICAL NEUROPSYCHOLOGY
# >
# > Department of General Psychology
#
# ---
# A.A. 2020/21 (6 CFU) - Dr. Alberto Testolin, Dr. Matteo Gadaleta
# ---
#
#
# ##Lab. 03 - PyTorch regression

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %% [markdown]
# # Practical example: Linear Regression

# %% [markdown]
# Now let's solve the same problem analyzed in one of the previous lab using a simple neural network implemented in PyTorch.

# %% [markdown]
# # Data generation

# %% [markdown]
# Let's generate some data with our usual polynomial model, and save the data points in two csv files, one for training (train_data.csv), and one for validation (val_data.csv).
#
# You can find these files in the "Files" section of Colab. They are not stored in your local machine, but they are stored remotely in the Colab server.

# %%
def poly_model(x, beta, noise_std=0):
    """
    INPUT
        x: x vector
        beta: polynomial parameters
        noise_std: enable noisy sampling (gaussian noise, zero mean, noise_std std)
    """
    pol_order = len(beta)
    x_matrix = np.array([x**i for i in range(pol_order)]).transpose()
    y = np.matmul(x_matrix, beta)
    noise = np.random.randn(len(y)) * noise_std
    return y + noise

beta_true = [-1.45, 1.12, 2.3]
noise_std = 0.2
np.random.seed(4)

### Train data
num_train_points = 20
x_train = np.random.rand(num_train_points)
y_train = poly_model(x_train, beta_true, noise_std)
with open('train_data.csv', 'w') as f:
    data = [f"{x},{y}" for x, y in zip(x_train, y_train)]
    f.write('\n'.join(data))
    
### Validation data
num_val_points = 20
x_val = np.random.rand(num_val_points)
y_val = poly_model(x_val, beta_true, noise_std)
with open('val_data.csv', 'w') as f:
    data = [f"{x},{y}" for x, y in zip(x_val, y_val)]
    f.write('\n'.join(data))

### Plot
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_val, y_val, color='g', ls='', marker='.', label='Validation data points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Network Training

# %% [markdown]
# ## Network Definition

# %% [markdown]
# Define a fully connected feed-forward network with 2 hidden layers.
#
# Use a sigmoid activation function.
#
# Since this is a regression, we do not want to limit the value of the output. For this reason, NO activation function should be used for the output layer.

# %%
class Net(nn.Module):
    
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()
        
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.act = nn.Sigmoid()

        print('Network initialized')
        
    def forward(self, x, additional_out=False):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.out(x)
        return x

# %% [markdown]
# ## Dataset and Dataloader

# %% [markdown]
# We have already implemented the dataset class in the previous lab.

# %% [markdown]
# ### Dataset

# %%
class CsvDataset(Dataset):

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        # Read the file and split the lines in a list

        with open(csv_file, 'r') as f:
            lines = f.read().split('\n')

        # Get x and y values from each line and append to self.data

        self.data = []
        for line in lines:
            sample = line.split(',')
            self.data.append((float(sample[0]), float(sample[1])))

        # Now self.data contains all our dataset.
        # Each element of the list self.data is a tuple: (input, output)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
    
        sample = self.data[idx]
        if self.transform:
            sample = self.transform(sample)
        return sample

# %% [markdown]
# ### Transforms

# %%
class ToTensor(object):
    """Convert sample to Tensors."""

    def __call__(self, sample):
        x, y = sample
        return (torch.Tensor([x]).float(),
            torch.Tensor([y]).float())

# %%
composed_transform = transforms.Compose([ToTensor()])

train_dataset = CsvDataset('train_data.csv', transform=composed_transform)
val_dataset   = CsvDataset('val_data.csv', transform=composed_transform)
# Out:
# <__main__.CsvDataset object at 0x000002C7C1B7C8C8>

# %% [markdown]
# ### Dataloader

# %% [markdown]
# For the dataloader:
#
# * enable the shuffling only for training data
# * try different values for batch size
# * disable the multiprocessing

# %%
train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, num_workers=0)
val_dataloader   = DataLoader(val_dataset, batch_size=len(val_dataset), shuffle=True, num_workers=0)

# %% [markdown]
# ## Training loop

# %% [markdown]
# Now we put together all the steps analyzed in the previous lab:

# %%
# Check if the GPU is available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f"Training device: {device}")
# Out:
# Training device: cuda

# %%
# Initialize the network and move the parameters to the proper device

torch.manual_seed(0)

Ni = 1
Nh1 = 128
Nh2 = 256
No = 1

net=Net(Ni,Nh1,Nh2,No)

net.to(device)
# Out:
# Network initialized
# Net(
#   (fc1): Linear(in_features=1, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=256, bias=True)
#   (out): Linear(in_features=256, out_features=1, bias=True)
#   (act): Sigmoid()
# )

# %%
# Define the loss function

loss_function = nn.MSELoss()

# %%
# Define the optimizer

optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
### TRAINING LOOP
num_epochs = 10
train_loss_log = []
val_loss_log = []
for epoch_num in range(num_epochs):
    print('#################')
    print(f'# EPOCH {epoch_num}')
    print('#################')

    ### TRAIN
    train_loss= []
    net.train() # Training mode (e.g. enable dropout)
    for sample_batched in train_dataloader:
        # Move data to device
        x_batch=sample_batched[0].to(device)
        label_batch=sample_batched[1].to(device)
        # Forward pass
        out=net(x_batch)

        # Compute loss
        loss=loss_function(out,label_batch)

        # Backpropagation
        net.zero_grad()
        loss.backward()

        # Update the weights
        optimizer.step()

        # Save train loss for this batch
        loss_batch = loss.detach().cpu().numpy()
        train_loss.append(loss_batch)

    # Save average train loss
    train_loss = np.mean(train_loss)
    print(f"AVERAGE TRAIN LOSS: {train_loss}")
    train_loss_log.append(train_loss)

    ### VALIDATION
    val_loss= []
    net.eval() # Evaluation mode (e.g. disable dropout)
    with torch.no_grad(): # Disable gradient tracking
        for sample_batched in val_dataloader:
            # Move data to device
            x_batch=sample_batched[0].to(device)
            label_batch=sample_batched[1].to(device)

            # Forward pass
            out=net(x_batch)

            # Compute loss
            loss=loss_function(out,label_batch)

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)

        # Save average validation loss
        val_loss = np.mean(val_loss)
        print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
        val_loss_log.append(val_loss)
# Out:
# #################
# # EPOCH 0
# #################
# [tensor([[0.1977],
#         [0.6977],
#         [0.9763],
#         [0.8630]]), tensor([[-1.1278],
#         [ 0.2198],
#         [ 1.7142],
#         [ 1.2615]])]
# tensor([[0.1977],
#         [0.6977],
#         [0.9763],
#         [0.8630]], device='cuda:0')
# [tensor([[0.0062],
#         [0.7148],
#         [0.0442],
#         [0.3866]]), tensor([[-1.1335],
#         [ 0.5923],
#         [-1.0689],
#         [-0.8959]])]
# tensor([[0.0062],
#         [0.7148],
#         [0.0442],
#         [0.3866]], device='cuda:0')
# [tensor([[0.2161],
#         [0.2530],
#         [0.7794],
#         [0.4348]]), tensor([[-1.0304],
#         [-0.8748],
#         [ 0.6234],
#         [-0.5190]])]
# tensor([[0.2161],
#         [0.2530],
#         [0.7794],
#         [0.4348]], device='cuda:0')
# [tensor([[0.0090],
#         [0.5472],
#         [0.9727],
#         [0.5973]]), tensor([[-1.1013],
#         [-0.1659],
#         [ 1.9005],
#         [ 0.1185]])]
# tensor([[0.0090],
#         [0.5472],
#         [0.9727],
#         [0.5973]], device='cuda:0')
# [tensor([[0.9670],
#         [0.9834],
#         [0.9567],
#         [0.1638]]), tensor([[ 1.9076],
#         [ 1.6339],
#         [ 1.4542],
#         [-0.7601]])]
# tensor([[0.9670],
#         [0.9834],
#         [0.9567],
#         [0.1638]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.510533332824707
# AVERAGE VAL LOSS: 0.9322575926780701
# #################
# # EPOCH 1
# #################
# [tensor([[0.7794],
#         [0.0090],
#         [0.8630],
#         [0.6977]]), tensor([[ 0.6234],
#         [-1.1013],
#         [ 1.2615],
#         [ 0.2198]])]
# tensor([[0.7794],
#         [0.0090],
#         [0.8630],
#         [0.6977]], device='cuda:0')
# [tensor([[0.5472],
#         [0.1977],
#         [0.9763],
#         [0.4348]]), tensor([[-0.1659],
#         [-1.1278],
#         [ 1.7142],
#         [-0.5190]])]
# tensor([[0.5472],
#         [0.1977],
#         [0.9763],
#         [0.4348]], device='cuda:0')
# [tensor([[0.9834],
#         [0.7148],
#         [0.9670],
#         [0.0442]]), tensor([[ 1.6339],
#         [ 0.5923],
#         [ 1.9076],
#         [-1.0689]])]
# tensor([[0.9834],
#         [0.7148],
#         [0.9670],
#         [0.0442]], device='cuda:0')
# [tensor([[0.5973],
#         [0.0062],
#         [0.1638],
#         [0.2530]]), tensor([[ 0.1185],
#         [-1.1335],
#         [-0.7601],
#         [-0.8748]])]
# tensor([[0.5973],
#         [0.0062],
#         [0.1638],
#         [0.2530]], device='cuda:0')
# [tensor([[0.3866],
#         [0.9567],
#         [0.9727],
#         [0.2161]]), tensor([[-0.8959],
#         [ 1.4542],
#         [ 1.9005],
#         [-1.0304]])]
# tensor([[0.3866],
#         [0.9567],
#         [0.9727],
#         [0.2161]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.2718766927719116
# AVERAGE VAL LOSS: 0.9232534766197205
# #################
# # EPOCH 2
# #################
# [tensor([[0.7794],
#         [0.2161],
#         [0.9567],
#         [0.9834]]), tensor([[ 0.6234],
#         [-1.0304],
#         [ 1.4542],
#         [ 1.6339]])]
# tensor([[0.7794],
#         [0.2161],
#         [0.9567],
#         [0.9834]], device='cuda:0')
# [tensor([[0.2530],
#         [0.8630],
#         [0.7148],
#         [0.0090]]), tensor([[-0.8748],
#         [ 1.2615],
#         [ 0.5923],
#         [-1.1013]])]
# tensor([[0.2530],
#         [0.8630],
#         [0.7148],
#         [0.0090]], device='cuda:0')
# [tensor([[0.9763],
#         [0.0062],
#         [0.4348],
#         [0.5472]]), tensor([[ 1.7142],
#         [-1.1335],
#         [-0.5190],
#         [-0.1659]])]
# tensor([[0.9763],
#         [0.0062],
#         [0.4348],
#         [0.5472]], device='cuda:0')
# [tensor([[0.1977],
#         [0.9670],
#         [0.9727],
#         [0.3866]]), tensor([[-1.1278],
#         [ 1.9076],
#         [ 1.9005],
#         [-0.8959]])]
# tensor([[0.1977],
#         [0.9670],
#         [0.9727],
#         [0.3866]], device='cuda:0')
# [tensor([[0.6977],
#         [0.0442],
#         [0.1638],
#         [0.5973]]), tensor([[ 0.2198],
#         [-1.0689],
#         [-0.7601],
#         [ 0.1185]])]
# tensor([[0.6977],
#         [0.0442],
#         [0.1638],
#         [0.5973]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.2541050910949707
# AVERAGE VAL LOSS: 0.9522280693054199
# #################
# # EPOCH 3
# #################
# [tensor([[0.0442],
#         [0.8630],
#         [0.5472],
#         [0.6977]]), tensor([[-1.0689],
#         [ 1.2615],
#         [-0.1659],
#         [ 0.2198]])]
# tensor([[0.0442],
#         [0.8630],
#         [0.5472],
#         [0.6977]], device='cuda:0')
# [tensor([[0.9670],
#         [0.1638],
#         [0.7148],
#         [0.2161]]), tensor([[ 1.9076],
#         [-0.7601],
#         [ 0.5923],
#         [-1.0304]])]
# tensor([[0.9670],
#         [0.1638],
#         [0.7148],
#         [0.2161]], device='cuda:0')
# [tensor([[0.2530],
#         [0.9567],
#         [0.9834],
#         [0.7794]]), tensor([[-0.8748],
#         [ 1.4542],
#         [ 1.6339],
#         [ 0.6234]])]
# tensor([[0.2530],
#         [0.9567],
#         [0.9834],
#         [0.7794]], device='cuda:0')
# [tensor([[0.9763],
#         [0.5973],
#         [0.3866],
#         [0.0062]]), tensor([[ 1.7142],
#         [ 0.1185],
#         [-0.8959],
#         [-1.1335]])]
# tensor([[0.9763],
#         [0.5973],
#         [0.3866],
#         [0.0062]], device='cuda:0')
# [tensor([[0.4348],
#         [0.0090],
#         [0.1977],
#         [0.9727]]), tensor([[-0.5190],
#         [-1.1013],
#         [-1.1278],
#         [ 1.9005]])]
# tensor([[0.4348],
#         [0.0090],
#         [0.1977],
#         [0.9727]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.2130292654037476
# AVERAGE VAL LOSS: 0.945346474647522
# #################
# # EPOCH 4
# #################
# [tensor([[0.0090],
#         [0.9670],
#         [0.4348],
#         [0.9763]]), tensor([[-1.1013],
#         [ 1.9076],
#         [-0.5190],
#         [ 1.7142]])]
# tensor([[0.0090],
#         [0.9670],
#         [0.4348],
#         [0.9763]], device='cuda:0')
# [tensor([[0.5472],
#         [0.9567],
#         [0.5973],
#         [0.1638]]), tensor([[-0.1659],
#         [ 1.4542],
#         [ 0.1185],
#         [-0.7601]])]
# tensor([[0.5472],
#         [0.9567],
#         [0.5973],
#         [0.1638]], device='cuda:0')
# [tensor([[0.3866],
#         [0.2161],
#         [0.6977],
#         [0.1977]]), tensor([[-0.8959],
#         [-1.0304],
#         [ 0.2198],
#         [-1.1278]])]
# tensor([[0.3866],
#         [0.2161],
#         [0.6977],
#         [0.1977]], device='cuda:0')
# [tensor([[0.0442],
#         [0.9834],
#         [0.7794],
#         [0.7148]]), tensor([[-1.0689],
#         [ 1.6339],
#         [ 0.6234],
#         [ 0.5923]])]
# tensor([[0.0442],
#         [0.9834],
#         [0.7794],
#         [0.7148]], device='cuda:0')
# [tensor([[0.2530],
#         [0.8630],
#         [0.9727],
#         [0.0062]]), tensor([[-0.8748],
#         [ 1.2615],
#         [ 1.9005],
#         [-1.1335]])]
# tensor([[0.2530],
#         [0.8630],
#         [0.9727],
#         [0.0062]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.1924800872802734
# AVERAGE VAL LOSS: 0.8994402289390564
# #################
# # EPOCH 5
# #################
# [tensor([[0.2161],
#         [0.4348],
#         [0.9834],
#         [0.1977]]), tensor([[-1.0304],
#         [-0.5190],
#         [ 1.6339],
#         [-1.1278]])]
# tensor([[0.2161],
#         [0.4348],
#         [0.9834],
#         [0.1977]], device='cuda:0')
# [tensor([[0.7148],
#         [0.3866],
#         [0.0090],
#         [0.0442]]), tensor([[ 0.5923],
#         [-0.8959],
#         [-1.1013],
#         [-1.0689]])]
# tensor([[0.7148],
#         [0.3866],
#         [0.0090],
#         [0.0442]], device='cuda:0')
# [tensor([[0.2530],
#         [0.8630],
#         [0.9670],
#         [0.6977]]), tensor([[-0.8748],
#         [ 1.2615],
#         [ 1.9076],
#         [ 0.2198]])]
# tensor([[0.2530],
#         [0.8630],
#         [0.9670],
#         [0.6977]], device='cuda:0')
# [tensor([[0.5973],
#         [0.9763],
#         [0.5472],
#         [0.9567]]), tensor([[ 0.1185],
#         [ 1.7142],
#         [-0.1659],
#         [ 1.4542]])]
# tensor([[0.5973],
#         [0.9763],
#         [0.5472],
#         [0.9567]], device='cuda:0')
# [tensor([[0.0062],
#         [0.9727],
#         [0.1638],
#         [0.7794]]), tensor([[-1.1335],
#         [ 1.9005],
#         [-0.7601],
#         [ 0.6234]])]
# tensor([[0.0062],
#         [0.9727],
#         [0.1638],
#         [0.7794]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.2034430503845215
# AVERAGE VAL LOSS: 0.8631619811058044
# #################
# # EPOCH 6
# #################
# [tensor([[0.7794],
#         [0.0062],
#         [0.5472],
#         [0.9670]]), tensor([[ 0.6234],
#         [-1.1335],
#         [-0.1659],
#         [ 1.9076]])]
# tensor([[0.7794],
#         [0.0062],
#         [0.5472],
#         [0.9670]], device='cuda:0')
# [tensor([[0.9834],
#         [0.2161],
#         [0.7148],
#         [0.9567]]), tensor([[ 1.6339],
#         [-1.0304],
#         [ 0.5923],
#         [ 1.4542]])]
# tensor([[0.9834],
#         [0.2161],
#         [0.7148],
#         [0.9567]], device='cuda:0')
# [tensor([[0.1638],
#         [0.0442],
#         [0.2530],
#         [0.6977]]), tensor([[-0.7601],
#         [-1.0689],
#         [-0.8748],
#         [ 0.2198]])]
# tensor([[0.1638],
#         [0.0442],
#         [0.2530],
#         [0.6977]], device='cuda:0')
# [tensor([[0.3866],
#         [0.0090],
#         [0.4348],
#         [0.5973]]), tensor([[-0.8959],
#         [-1.1013],
#         [-0.5190],
#         [ 0.1185]])]
# tensor([[0.3866],
#         [0.0090],
#         [0.4348],
#         [0.5973]], device='cuda:0')
# [tensor([[0.9763],
#         [0.1977],
#         [0.9727],
#         [0.8630]]), tensor([[ 1.7142],
#         [-1.1278],
#         [ 1.9005],
#         [ 1.2615]])]
# tensor([[0.9763],
#         [0.1977],
#         [0.9727],
#         [0.8630]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.155082106590271
# AVERAGE VAL LOSS: 0.8747695088386536
# #################
# # EPOCH 7
# #################
# [tensor([[0.3866],
#         [0.9727],
#         [0.7794],
#         [0.6977]]), tensor([[-0.8959],
#         [ 1.9005],
#         [ 0.6234],
#         [ 0.2198]])]
# tensor([[0.3866],
#         [0.9727],
#         [0.7794],
#         [0.6977]], device='cuda:0')
# [tensor([[0.9763],
#         [0.1638],
#         [0.8630],
#         [0.2530]]), tensor([[ 1.7142],
#         [-0.7601],
#         [ 1.2615],
#         [-0.8748]])]
# tensor([[0.9763],
#         [0.1638],
#         [0.8630],
#         [0.2530]], device='cuda:0')
# [tensor([[0.0090],
#         [0.0442],
#         [0.4348],
#         [0.2161]]), tensor([[-1.1013],
#         [-1.0689],
#         [-0.5190],
#         [-1.0304]])]
# tensor([[0.0090],
#         [0.0442],
#         [0.4348],
#         [0.2161]], device='cuda:0')
# [tensor([[0.0062],
#         [0.1977],
#         [0.9670],
#         [0.9834]]), tensor([[-1.1335],
#         [-1.1278],
#         [ 1.9076],
#         [ 1.6339]])]
# tensor([[0.0062],
#         [0.1977],
#         [0.9670],
#         [0.9834]], device='cuda:0')
# [tensor([[0.5472],
#         [0.5973],
#         [0.9567],
#         [0.7148]]), tensor([[-0.1659],
#         [ 0.1185],
#         [ 1.4542],
#         [ 0.5923]])]
# tensor([[0.5472],
#         [0.5973],
#         [0.9567],
#         [0.7148]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.1219773292541504
# AVERAGE VAL LOSS: 0.8788291811943054
# #################
# # EPOCH 8
# #################
# [tensor([[0.9670],
#         [0.5472],
#         [0.7794],
#         [0.1977]]), tensor([[ 1.9076],
#         [-0.1659],
#         [ 0.6234],
#         [-1.1278]])]
# tensor([[0.9670],
#         [0.5472],
#         [0.7794],
#         [0.1977]], device='cuda:0')
# [tensor([[0.0062],
#         [0.3866],
#         [0.0442],
#         [0.0090]]), tensor([[-1.1335],
#         [-0.8959],
#         [-1.0689],
#         [-1.1013]])]
# tensor([[0.0062],
#         [0.3866],
#         [0.0442],
#         [0.0090]], device='cuda:0')
# [tensor([[0.9567],
#         [0.9727],
#         [0.2161],
#         [0.5973]]), tensor([[ 1.4542],
#         [ 1.9005],
#         [-1.0304],
#         [ 0.1185]])]
# tensor([[0.9567],
#         [0.9727],
#         [0.2161],
#         [0.5973]], device='cuda:0')
# [tensor([[0.6977],
#         [0.1638],
#         [0.7148],
#         [0.9834]]), tensor([[ 0.2198],
#         [-0.7601],
#         [ 0.5923],
#         [ 1.6339]])]
# tensor([[0.6977],
#         [0.1638],
#         [0.7148],
#         [0.9834]], device='cuda:0')
# [tensor([[0.2530],
#         [0.9763],
#         [0.4348],
#         [0.8630]]), tensor([[-0.8748],
#         [ 1.7142],
#         [-0.5190],
#         [ 1.2615]])]
# tensor([[0.2530],
#         [0.9763],
#         [0.4348],
#         [0.8630]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.102104663848877
# AVERAGE VAL LOSS: 0.8426889777183533
# #################
# # EPOCH 9
# #################
# [tensor([[0.8630],
#         [0.5472],
#         [0.3866],
#         [0.0090]]), tensor([[ 1.2615],
#         [-0.1659],
#         [-0.8959],
#         [-1.1013]])]
# tensor([[0.8630],
#         [0.5472],
#         [0.3866],
#         [0.0090]], device='cuda:0')
# [tensor([[0.5973],
#         [0.0062],
#         [0.2530],
#         [0.6977]]), tensor([[ 0.1185],
#         [-1.1335],
#         [-0.8748],
#         [ 0.2198]])]
# tensor([[0.5973],
#         [0.0062],
#         [0.2530],
#         [0.6977]], device='cuda:0')
# [tensor([[0.0442],
#         [0.9834],
#         [0.9763],
#         [0.1638]]), tensor([[-1.0689],
#         [ 1.6339],
#         [ 1.7142],
#         [-0.7601]])]
# tensor([[0.0442],
#         [0.9834],
#         [0.9763],
#         [0.1638]], device='cuda:0')
# [tensor([[0.9567],
#         [0.4348],
#         [0.1977],
#         [0.7794]]), tensor([[ 1.4542],
#         [-0.5190],
#         [-1.1278],
#         [ 0.6234]])]
# tensor([[0.9567],
#         [0.4348],
#         [0.1977],
#         [0.7794]], device='cuda:0')
# [tensor([[0.9670],
#         [0.7148],
#         [0.9727],
#         [0.2161]]), tensor([[ 1.9076],
#         [ 0.5923],
#         [ 1.9005],
#         [-1.0304]])]
# tensor([[0.9670],
#         [0.7148],
#         [0.9727],
#         [0.2161]], device='cuda:0')
# AVERAGE TRAIN LOSS: 1.0749778747558594
# AVERAGE VAL LOSS: 0.8130401968955994

# %% [markdown]
# ### Plot losses

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(val_loss_log, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# # Network analysis

# %% [markdown]
# ## Network output

# %%
# Input vector
x_vec = torch.linspace(0,1,1000)
x_vec = x_vec.to(device)
x_vec = x_vec.unsqueeze(-1)
print(f"Input shape: {x_vec.shape}")

# Network output
with torch.no_grad():
    y_vec = net(x_vec)
print(f"Output shape: {y_vec.shape}")

# Expected output
beta_true = [-1.45, 1.12, 2.3]
true_model = poly_model(x_vec.cpu().numpy(), beta_true).squeeze()
# Out:
# Input shape: torch.Size([1000, 1])
# Output shape: torch.Size([1000, 1])

# %%
# Convert x_vec and y_vec to numpy one dimensional arrays
x_vec = x_vec.squeeze().cpu().numpy()
y_vec = y_vec.squeeze().cpu().numpy()

# Plot output
plt.figure(figsize=(12,8))
plt.plot(x_vec, y_vec, label='Network output')
plt.plot(x_vec, true_model, label='True model')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Access network parameters

# %%
# First hidden layer
h1_w = net.fc1.weight.data.cpu().numpy()
h1_b = net.fc1.bias.data.cpu().numpy()

# Second hidden layer
h2_w = net.fc2.weight.data.cpu().numpy()
h2_b = net.fc2.bias.data.cpu().numpy()

# Output layer
out_w = net.out.weight.data.cpu().numpy()
out_b = net.out.bias.data.cpu().numpy()

# %% [markdown]
# ## Weights histogram

# %%
# Weights histogram
fig, axs = plt.subplots(3, 1, figsize=(12,8))
axs[0].hist(h1_w.flatten(), 50)
axs[0].set_title('First hidden layer weights')
axs[1].hist(h2_w.flatten(), 50)
axs[1].set_title('Second hidden layer weights')
axs[2].hist(out_w.flatten(), 50)
axs[2].set_title('Output layer weights')
[ax.grid() for ax in axs]
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save network parameters

# %% [markdown]
# ### Save network

# %%
### Save network parameters
### Save the network state
# The state dictionary includes all the parameters of the network
net_state_dict = net.state_dict()
# Save the state dict to a file
torch.save(net_state_dict, 'net_parameters.torch')

# %% [markdown]
# ### Load network

# %%
### Reload the network state
# First initialize the network (if not already done)
net = Net(Ni, Nh1, Nh2, No) 
# Load the state dict previously saved
net_state_dict = torch.load('net_parameters.torch')
# Update the network parameters
net.load_state_dict(net_state_dict)
# Out:
# Network initialized
# <All keys matched successfully>

# %% [markdown]
# ## Save optimizer state
# Also the optimizer has its internal state!
#
# You need to save both the network and the optimizer states if you want to continue your training.
#
# If you are sure you have finished your training you can just save the network.

# %%
### Save the optimizer state
torch.save(optimizer.state_dict(), 'optimizer_state.torch')

### Reload the optimizer state
optimizer = optim.Adam(net.parameters(), lr=0.001)
opt_state_dict = torch.load('optimizer_state.torch')
optimizer.load_state_dict(opt_state_dict)

# %% [markdown]
# ## Analyze activations

# %%
def get_activation(layer, input, output):
    global activation
    activation = torch.sigmoid(output)

### Register hook  
hook_handle = net.fc2.register_forward_hook(get_activation)

### Analyze activations
net = net.to(device)
net.eval()
with torch.no_grad():
    x1 = torch.tensor([0.1]).float().to(device)
    y1 = net(x1)
    z1 = activation
    x2 = torch.tensor([0.9]).float().to(device)
    y2 = net(x2)
    z2 = activation
    x3 = torch.tensor([2.5]).float().to(device)
    y3 = net(x3)
    z3 = activation

### Remove hook
hook_handle.remove()

### Plot activations
fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1.cpu().numpy(), use_line_collection=True)
axs[0].set_title('Last layer activations for input x=%.2f' % x1)
axs[1].stem(z2.cpu().numpy(), use_line_collection=True)
axs[1].set_title('Last layer activations for input x=%.2f' % x2)
axs[2].stem(z3.cpu().numpy(), use_line_collection=True)
axs[2].set_title('Last layer activations for input x=%.2f' % x3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exercise - Classification model

# %% [markdown]
# **HINTS**
# - Choose a loss function that is suitable for the specific problem, a binary classification in this case. If you keep a single linear output you can use a BCEWithLogitsLoss, which is more numerically stable than manually using a sigmoid output activation (more info here: https://pytorch.org/docs/stable/generated/torch.nn.BCEWithLogitsLoss.html).
# - The network now has 2 inputs. A batched input should have a shape $\text{batch_size} \times 2$.
# - The dataset should be adapted accordingly. Also consider to increase the batch size.
# - Explore different optimizers, trying to understand the differences and their parameters (https://pytorch.org/docs/stable/optim.html).
# - Try to increase the complexity of the network, and at the same time to introduce some regularization with dropout layers and/or weight decay (which is equivalent to an L2 regularization, typically implemented by the optimizer).
# - Experiment with different hyper-parameters trying to minimize the VALIDATION LOSS. Once you are happy with the result, try the final test with the TEST dataset.

# %% [markdown]
# ## Data generation

# %%
import itertools

np.random.seed(123)

def bidimensional_model(x1, x2):
    a = 1
    b = 1
    cx1 = 0
    cx2 = 0
    out = (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 2
    cx1 = 5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 1
    b = 2
    cx1 = -2.5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 3
    b = 1
    cx1 = -6
    cx2 = -2.5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 4
    cx1 = -7.5
    cx2 = -5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 6
    b = 1
    cx1 = -7.5
    cx2 = 5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 4
    b = 4
    cx1 = 7.5
    cx2 = -7.5
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 3
    b = 2
    cx1 = -1
    cx2 = -6
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 5
    cx1 = 1
    cx2 = 6
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    a = 2
    b = 2
    cx1 = 6
    cx2 = 0
    out |= (x1 - cx1)**2 / a**2 + (x2 - cx2)**2 / b **2 < 1
    return out.astype(int)

### PLOT MODEL
# Input grid
x1 = np.linspace(-10, 10, 400)
x2 = np.linspace(-10, 10, 400)
x_prod = [x for x in itertools.product(x1, x2)]
x1 = np.array([x[0] for x in x_prod])
x2 = np.array([x[1] for x in x_prod])
# Evaluate out
y = bidimensional_model(x1, x2)
# Scatter plot
fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=y, s=1, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
fig.show()
# Out:
# C:\Users\stefano\.conda\envs\gputest\lib\site-packages\ipykernel_launcher.py:72: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ### Training points

# %%
import pandas as pd

### Train data
num_points = 1000
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
train_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
train_df.to_csv('classifier_train_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=y, s=1, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Training points')
fig.show()
# Out:
# C:\Users\stefano\.conda\envs\gputest\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   app.launch_new_instance()

# %% [markdown]
# ### Validation points

# %% [markdown]
# Validation points are randomly selected from the training points (20% in this case).

# %%
### Validation data
num_points = 200
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
val_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
val_df.to_csv('classifier_val_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=y, s=1, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Validation points')
fig.show()
# Out:
# C:\Users\stefano\.conda\envs\gputest\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ### Test points

# %%
### Test data
num_points = 400
x1 = np.random.uniform(-10, 10, num_points)
x2 = np.random.uniform(-10, 10, num_points)
y = bidimensional_model(x1, x2)
val_df = pd.DataFrame({'x1': x1, 'x2': x2, 'y': y})
val_df.to_csv('classifier_test_data.csv', index=False)

fig, ax = plt.subplots(figsize=(12,8))
ax.scatter(x1, x2, c=y, s=1, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Test points')
fig.show()
# Out:
# C:\Users\stefano\.conda\envs\gputest\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Dataset and Dataloader

# %% [markdown]
# Define the dataset

# %%
class ClassifierDataset(Dataset):

    def __init__(self, csv_file, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        # Read the file and store the content in a pandas DataFrame
        self.df = pd.read_csv(csv_file)

    def __len__(self):
        # The length of the dataset is simply the length of the self.data list
        return len(self.df)

    def __getitem__(self, idx):
        # Our sample is the row at index idx of the dataframe
        row = self.df.iloc[idx]
        # There are 2 inputs this time
        sample = ([row.x1, row.x2], row.y)
        if self.transform:
            sample = self.transform(sample)
        return sample

# %% [markdown]
# Define the transformations

# %%
class ToTensor(object):
    """Convert sample to Tensors."""

    def __call__(self, sample):
        x, y = sample
        return (torch.Tensor(x).float(),
                torch.Tensor([y]).float())

# %% [markdown]
# Initialize the datasets

# %%
composed_transform = transforms.Compose([ToTensor()])

train_dataset = ClassifierDataset('classifier_train_data.csv', transform=composed_transform)
val_dataset   = ClassifierDataset('classifier_val_data.csv', transform=composed_transform)
test_dataset  = ClassifierDataset('classifier_test_data.csv', transform=composed_transform)

# %% [markdown]
# Define the dataloaders

# %%
train_dataloader = DataLoader(train_dataset, batch_size=200, shuffle=True, num_workers=0)
val_dataloader   = DataLoader(val_dataset, batch_size=len(val_dataset), shuffle=False, num_workers=0)
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset), shuffle=False, num_workers=0)

# %% [markdown]
# ## Network definition

# %%
class Net(nn.Module):
    
    def __init__(self, Ni, Nh1, Nh2, No):
        """
        Ni - Input size
        Nh1 - Neurons in the 1st hidden layer
        Nh2 - Neurons in the 2nd hidden layer
        No - Output size
        """
        super().__init__()
        
        print('Network initialized')
        self.fc1 = nn.Linear(in_features=Ni, out_features=Nh1)
        self.fc2 = nn.Linear(in_features=Nh1, out_features=Nh2)
        self.out = nn.Linear(in_features=Nh2, out_features=No)
        self.act = nn.Sigmoid()
        
    def forward(self, x, additional_out=False):
        x = self.act(self.fc1(x))
        x = self.act(self.fc2(x))
        x = self.out(x)
        return x

# %% [markdown]
# ## Training loop

# %% [markdown]
# Some initializations

# %%
# Initialize the network
torch.manual_seed(0)
Ni = 2
Nh1 = 128
Nh2 = 256
No = 1
net = Net(Ni, Nh1, Nh2, No)
net.to(device)

# Define the loss function
loss_fn = nn.BCEWithLogitsLoss()

# Define the optimizer
optimizer = optim.Adam(net.parameters(), lr=1e-2)
# Out:
# Network initialized

# %% [markdown]
# Training loop

# %%
### TRAINING LOOP
num_epochs = 600
train_loss_log = []
val_loss_log = []
for epoch_num in range(num_epochs):
    print('#################')
    print(f'# EPOCH {epoch_num}')
    print('#################')

    ### TRAIN
    train_loss= []
    net.train() # Training mode (e.g. enable dropout)
    for sample_batched in train_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)

        # Forward pass
        out = net(x_batch)

        # Compute loss
        loss = loss_fn(out, label_batch)

        # Backpropagation
        net.zero_grad()
        loss.backward()

        # Update the weights
        optimizer.step()

        # Save train loss for this batch
        loss_batch = loss.detach().cpu().numpy()
        train_loss.append(loss_batch)

    # Save average train loss
    train_loss = np.mean(train_loss)
    print(f"AVERAGE TRAIN LOSS: {train_loss}")
    train_loss_log.append(train_loss)

    ### VALIDATION
    val_loss= []
    net.eval() # Evaluation mode (e.g. disable dropout)
    with torch.no_grad(): # Disable gradient tracking
        for sample_batched in val_dataloader:
            # Move data to device
            x_batch = sample_batched[0].to(device)
            label_batch = sample_batched[1].to(device)

            # Forward pass
            out = net(x_batch)

            # Compute loss
            loss = loss_fn(out, label_batch)

            # Save val loss for this batch
            loss_batch = loss.detach().cpu().numpy()
            val_loss.append(loss_batch)

        # Save average validation loss
        val_loss = np.mean(val_loss)
        print(f"AVERAGE VAL LOSS: {np.mean(val_loss)}")
        val_loss_log.append(val_loss)
# Out:
# #################
# # EPOCH 0
# #################
# AVERAGE TRAIN LOSS: 0.8095602989196777
# AVERAGE VAL LOSS: 0.6975054740905762
# #################
# # EPOCH 1
# #################
# AVERAGE TRAIN LOSS: 0.6957830190658569
# AVERAGE VAL LOSS: 0.7287846207618713
# #################
# # EPOCH 2
# #################
# AVERAGE TRAIN LOSS: 0.6709458827972412
# AVERAGE VAL LOSS: 0.6960254311561584
# #################
# # EPOCH 3
# #################
# AVERAGE TRAIN LOSS: 0.6551985740661621
# AVERAGE VAL LOSS: 0.6826837062835693
# #################
# # EPOCH 4
# #################
# AVERAGE TRAIN LOSS: 0.6530632972717285
# AVERAGE VAL LOSS: 0.6965773105621338
# #################
# # EPOCH 5
# #################
# AVERAGE TRAIN LOSS: 0.639805257320404
# AVERAGE VAL LOSS: 0.6697778701782227
# #################
# # EPOCH 6
# #################
# AVERAGE TRAIN LOSS: 0.629876434803009
# AVERAGE VAL LOSS: 0.6651046872138977
# #################
# # EPOCH 7
# #################
# AVERAGE TRAIN LOSS: 0.6149682998657227
# AVERAGE VAL LOSS: 0.6680211424827576
# #################
# # EPOCH 8
# #################
# AVERAGE TRAIN LOSS: 0.6037119030952454
# AVERAGE VAL LOSS: 0.6554813385009766
# #################
# # EPOCH 9
# #################
# AVERAGE TRAIN LOSS: 0.5921248197555542
# AVERAGE VAL LOSS: 0.645038902759552
# #################
# # EPOCH 10
# #################
# AVERAGE TRAIN LOSS: 0.5780068039894104
# AVERAGE VAL LOSS: 0.6481308341026306
# #################
# # EPOCH 11
# #################
# AVERAGE TRAIN LOSS: 0.5719935297966003
# AVERAGE VAL LOSS: 0.650797426700592
# #################
# # EPOCH 12
# #################
# AVERAGE TRAIN LOSS: 0.5686768293380737
# AVERAGE VAL LOSS: 0.6514740586280823
# #################
# # EPOCH 13
# #################
# AVERAGE TRAIN LOSS: 0.5636000633239746
# AVERAGE VAL LOSS: 0.6402381658554077
# #################
# # EPOCH 14
# #################
# AVERAGE TRAIN LOSS: 0.560778796672821
# AVERAGE VAL LOSS: 0.6340044140815735
# #################
# # EPOCH 15
# #################
# AVERAGE TRAIN LOSS: 0.5526422262191772
# AVERAGE VAL LOSS: 0.6266152262687683
# #################
# # EPOCH 16
# #################
# AVERAGE TRAIN LOSS: 0.5496416091918945
# AVERAGE VAL LOSS: 0.6187061071395874
# #################
# # EPOCH 17
# #################
# AVERAGE TRAIN LOSS: 0.5452097058296204
# AVERAGE VAL LOSS: 0.6180764436721802
# #################
# # EPOCH 18
# #################
# AVERAGE TRAIN LOSS: 0.5372336506843567
# AVERAGE VAL LOSS: 0.6152467131614685
# #################
# # EPOCH 19
# #################
# AVERAGE TRAIN LOSS: 0.5356456637382507
# AVERAGE VAL LOSS: 0.6065990924835205
# #################
# # EPOCH 20
# #################
# AVERAGE TRAIN LOSS: 0.5267548561096191
# AVERAGE VAL LOSS: 0.6082830429077148
# #################
# # EPOCH 21
# #################
# AVERAGE TRAIN LOSS: 0.5218251943588257
# AVERAGE VAL LOSS: 0.5937207937240601
# #################
# # EPOCH 22
# #################
# AVERAGE TRAIN LOSS: 0.5139574408531189
# AVERAGE VAL LOSS: 0.5950675010681152
# #################
# # EPOCH 23
# #################
# AVERAGE TRAIN LOSS: 0.5081256628036499
# AVERAGE VAL LOSS: 0.5828859210014343
# #################
# # EPOCH 24
# #################
# AVERAGE TRAIN LOSS: 0.5043269991874695
# AVERAGE VAL LOSS: 0.5825430154800415
# #################
# # EPOCH 25
# #################
# AVERAGE TRAIN LOSS: 0.49546805024147034
# AVERAGE VAL LOSS: 0.5756756663322449
# #################
# # EPOCH 26
# #################
# AVERAGE TRAIN LOSS: 0.486088365316391
# AVERAGE VAL LOSS: 0.563773512840271
# #################
# # EPOCH 27
# #################
# AVERAGE TRAIN LOSS: 0.4794483780860901
# AVERAGE VAL LOSS: 0.5713162422180176
# #################
# # EPOCH 28
# #################
# AVERAGE TRAIN LOSS: 0.4709957242012024
# AVERAGE VAL LOSS: 0.5551161170005798
# #################
# # EPOCH 29
# #################
# AVERAGE TRAIN LOSS: 0.47312575578689575
# AVERAGE VAL LOSS: 0.5491074919700623
# #################
# # EPOCH 30
# #################
# AVERAGE TRAIN LOSS: 0.45902958512306213
# AVERAGE VAL LOSS: 0.5562838315963745
# #################
# # EPOCH 31
# #################
# AVERAGE TRAIN LOSS: 0.45059823989868164
# AVERAGE VAL LOSS: 0.5436264872550964
# #################
# # EPOCH 32
# #################
# AVERAGE TRAIN LOSS: 0.4607556462287903
# AVERAGE VAL LOSS: 0.5804005265235901
# #################
# # EPOCH 33
# #################
# AVERAGE TRAIN LOSS: 0.452119916677475
# AVERAGE VAL LOSS: 0.5330454707145691
# #################
# # EPOCH 34
# #################
# AVERAGE TRAIN LOSS: 0.4474160075187683
# AVERAGE VAL LOSS: 0.540075421333313
# #################
# # EPOCH 35
# #################
# AVERAGE TRAIN LOSS: 0.4353959560394287
# AVERAGE VAL LOSS: 0.5483124256134033
# #################
# # EPOCH 36
# #################
# AVERAGE TRAIN LOSS: 0.4353903830051422
# AVERAGE VAL LOSS: 0.5147541761398315
# #################
# # EPOCH 37
# #################
# AVERAGE TRAIN LOSS: 0.42586174607276917
# AVERAGE VAL LOSS: 0.5143384337425232
# #################
# # EPOCH 38
# #################
# AVERAGE TRAIN LOSS: 0.4268738329410553
# AVERAGE VAL LOSS: 0.5415339469909668
# #################
# # EPOCH 39
# #################
# AVERAGE TRAIN LOSS: 0.4149765968322754
# AVERAGE VAL LOSS: 0.5140657424926758
# #################
# # EPOCH 40
# #################
# AVERAGE TRAIN LOSS: 0.4092969298362732
# AVERAGE VAL LOSS: 0.4983258843421936
# #################
# # EPOCH 41
# #################
# AVERAGE TRAIN LOSS: 0.41087856888771057
# AVERAGE VAL LOSS: 0.5058848261833191
# #################
# # EPOCH 42
# #################
# AVERAGE TRAIN LOSS: 0.41803058981895447
# AVERAGE VAL LOSS: 0.4965769052505493
# #################
# # EPOCH 43
# #################
# AVERAGE TRAIN LOSS: 0.40402522683143616
# AVERAGE VAL LOSS: 0.49914565682411194
# #################
# # EPOCH 44
# #################
# AVERAGE TRAIN LOSS: 0.3995678126811981
# AVERAGE VAL LOSS: 0.4877706468105316
# #################
# # EPOCH 45
# #################
# AVERAGE TRAIN LOSS: 0.3949670195579529
# AVERAGE VAL LOSS: 0.49210605025291443
# #################
# # EPOCH 46
# #################
# AVERAGE TRAIN LOSS: 0.3904660642147064
# AVERAGE VAL LOSS: 0.5036777853965759
# #################
# # EPOCH 47
# #################
# AVERAGE TRAIN LOSS: 0.3898307979106903
# AVERAGE VAL LOSS: 0.5181348919868469
# #################
# # EPOCH 48
# #################
# AVERAGE TRAIN LOSS: 0.38000762462615967
# AVERAGE VAL LOSS: 0.4906523525714874
# #################
# # EPOCH 49
# #################
# AVERAGE TRAIN LOSS: 0.36935335397720337
# AVERAGE VAL LOSS: 0.48840442299842834
# #################
# # EPOCH 50
# #################
# AVERAGE TRAIN LOSS: 0.3768804967403412
# AVERAGE VAL LOSS: 0.4798508286476135
# #################
# # EPOCH 51
# #################
# AVERAGE TRAIN LOSS: 0.3756774067878723
# AVERAGE VAL LOSS: 0.475423127412796
# #################
# # EPOCH 52
# #################
# AVERAGE TRAIN LOSS: 0.36772650480270386
# AVERAGE VAL LOSS: 0.4775562882423401
# #################
# # EPOCH 53
# #################
# AVERAGE TRAIN LOSS: 0.37669941782951355
# AVERAGE VAL LOSS: 0.4843028783798218
# #################
# # EPOCH 54
# #################
# AVERAGE TRAIN LOSS: 0.37116146087646484
# AVERAGE VAL LOSS: 0.47639700770378113
# #################
# # EPOCH 55
# #################
# AVERAGE TRAIN LOSS: 0.35741519927978516
# AVERAGE VAL LOSS: 0.46718665957450867
# #################
# # EPOCH 56
# #################
# AVERAGE TRAIN LOSS: 0.36336666345596313
# AVERAGE VAL LOSS: 0.4604671001434326
# #################
# # EPOCH 57
# #################
# AVERAGE TRAIN LOSS: 0.3625592589378357
# AVERAGE VAL LOSS: 0.4629877507686615
# #################
# # EPOCH 58
# #################
# AVERAGE TRAIN LOSS: 0.36141639947891235
# AVERAGE VAL LOSS: 0.5053122043609619
# #################
# # EPOCH 59
# #################
# AVERAGE TRAIN LOSS: 0.37133103609085083
# AVERAGE VAL LOSS: 0.5381369590759277
# #################
# # EPOCH 60
# #################
# AVERAGE TRAIN LOSS: 0.3611448407173157
# AVERAGE VAL LOSS: 0.4663853645324707
# #################
# # EPOCH 61
# #################
# AVERAGE TRAIN LOSS: 0.34613892436027527
# AVERAGE VAL LOSS: 0.4792167544364929
# #################
# # EPOCH 62
# #################
# AVERAGE TRAIN LOSS: 0.3378680646419525
# AVERAGE VAL LOSS: 0.4595735967159271
# #################
# # EPOCH 63
# #################
# AVERAGE TRAIN LOSS: 0.3457663953304291
# AVERAGE VAL LOSS: 0.4621490240097046
# #################
# # EPOCH 64
# #################
# AVERAGE TRAIN LOSS: 0.3531035780906677
# AVERAGE VAL LOSS: 0.44959181547164917
# #################
# # EPOCH 65
# #################
# AVERAGE TRAIN LOSS: 0.35377225279808044
# AVERAGE VAL LOSS: 0.4839775264263153
# #################
# # EPOCH 66
# #################
# AVERAGE TRAIN LOSS: 0.35672158002853394
# AVERAGE VAL LOSS: 0.45805636048316956
# #################
# # EPOCH 67
# #################
# AVERAGE TRAIN LOSS: 0.3431336581707001
# AVERAGE VAL LOSS: 0.44323158264160156
# #################
# # EPOCH 68
# #################
# AVERAGE TRAIN LOSS: 0.34796780347824097
# AVERAGE VAL LOSS: 0.46127554774284363
# #################
# # EPOCH 69
# #################
# AVERAGE TRAIN LOSS: 0.3408734202384949
# AVERAGE VAL LOSS: 0.5206553339958191
# #################
# # EPOCH 70
# #################
# AVERAGE TRAIN LOSS: 0.3371628522872925
# AVERAGE VAL LOSS: 0.4501858353614807
# #################
# # EPOCH 71
# #################
# AVERAGE TRAIN LOSS: 0.3293207585811615
# AVERAGE VAL LOSS: 0.45032262802124023
# #################
# # EPOCH 72
# #################
# AVERAGE TRAIN LOSS: 0.3200937509536743
# AVERAGE VAL LOSS: 0.44671890139579773
# #################
# # EPOCH 73
# #################
# AVERAGE TRAIN LOSS: 0.3254461884498596
# AVERAGE VAL LOSS: 0.4324556887149811
# #################
# # EPOCH 74
# #################
# AVERAGE TRAIN LOSS: 0.3313644528388977
# AVERAGE VAL LOSS: 0.4371649920940399
# #################
# # EPOCH 75
# #################
# AVERAGE TRAIN LOSS: 0.31940603256225586
# AVERAGE VAL LOSS: 0.4439849853515625
# #################
# # EPOCH 76
# #################
# AVERAGE TRAIN LOSS: 0.3103172779083252
# AVERAGE VAL LOSS: 0.4279319643974304
# #################
# # EPOCH 77
# #################
# AVERAGE TRAIN LOSS: 0.3229133188724518
# AVERAGE VAL LOSS: 0.4400028586387634
# #################
# # EPOCH 78
# #################
# AVERAGE TRAIN LOSS: 0.3203423023223877
# AVERAGE VAL LOSS: 0.45961326360702515
# #################
# # EPOCH 79
# #################
# AVERAGE TRAIN LOSS: 0.30636724829673767
# AVERAGE VAL LOSS: 0.43518194556236267
# #################
# # EPOCH 80
# #################
# AVERAGE TRAIN LOSS: 0.30919721722602844
# AVERAGE VAL LOSS: 0.478179931640625
# #################
# # EPOCH 81
# #################
# AVERAGE TRAIN LOSS: 0.3136715590953827
# AVERAGE VAL LOSS: 0.4608379304409027
# #################
# # EPOCH 82
# #################
# AVERAGE TRAIN LOSS: 0.3147764205932617
# AVERAGE VAL LOSS: 0.4249520003795624
# #################
# # EPOCH 83
# #################
# AVERAGE TRAIN LOSS: 0.3443080484867096
# AVERAGE VAL LOSS: 0.45774558186531067
# #################
# # EPOCH 84
# #################
# AVERAGE TRAIN LOSS: 0.33144593238830566
# AVERAGE VAL LOSS: 0.4338183104991913
# #################
# # EPOCH 85
# #################
# AVERAGE TRAIN LOSS: 0.33496853709220886
# AVERAGE VAL LOSS: 0.42889639735221863
# #################
# # EPOCH 86
# #################
# AVERAGE TRAIN LOSS: 0.3089694380760193
# AVERAGE VAL LOSS: 0.4540436565876007
# #################
# # EPOCH 87
# #################
# AVERAGE TRAIN LOSS: 0.2995114326477051
# AVERAGE VAL LOSS: 0.4147111773490906
# #################
# # EPOCH 88
# #################
# AVERAGE TRAIN LOSS: 0.295224130153656
# AVERAGE VAL LOSS: 0.4080120623111725
# #################
# # EPOCH 89
# #################
# AVERAGE TRAIN LOSS: 0.3058323264122009
# AVERAGE VAL LOSS: 0.44294485449790955
# #################
# # EPOCH 90
# #################
# AVERAGE TRAIN LOSS: 0.30445805191993713
# AVERAGE VAL LOSS: 0.49999889731407166
# #################
# # EPOCH 91
# #################
# AVERAGE TRAIN LOSS: 0.3133840262889862
# AVERAGE VAL LOSS: 0.41114288568496704
# #################
# # EPOCH 92
# #################
# AVERAGE TRAIN LOSS: 0.3119977116584778
# AVERAGE VAL LOSS: 0.3957842290401459
# #################
# # EPOCH 93
# #################
# AVERAGE TRAIN LOSS: 0.3214784562587738
# AVERAGE VAL LOSS: 0.4817039668560028
# #################
# # EPOCH 94
# #################
# AVERAGE TRAIN LOSS: 0.3087175488471985
# AVERAGE VAL LOSS: 0.4161430597305298
# #################
# # EPOCH 95
# #################
# AVERAGE TRAIN LOSS: 0.2975215017795563
# AVERAGE VAL LOSS: 0.411834716796875
# #################
# # EPOCH 96
# #################
# AVERAGE TRAIN LOSS: 0.3034265637397766
# AVERAGE VAL LOSS: 0.41409116983413696
# #################
# # EPOCH 97
# #################
# AVERAGE TRAIN LOSS: 0.2983299791812897
# AVERAGE VAL LOSS: 0.4637618064880371
# #################
# # EPOCH 98
# #################
# AVERAGE TRAIN LOSS: 0.2879015803337097
# AVERAGE VAL LOSS: 0.38870543241500854
# #################
# # EPOCH 99
# #################
# AVERAGE TRAIN LOSS: 0.28024983406066895
# AVERAGE VAL LOSS: 0.39431169629096985
# #################
# # EPOCH 100
# #################
# AVERAGE TRAIN LOSS: 0.2785310745239258
# AVERAGE VAL LOSS: 0.4186685085296631
# #################
# # EPOCH 101
# #################
# AVERAGE TRAIN LOSS: 0.28078657388687134
# AVERAGE VAL LOSS: 0.41930311918258667
# #################
# # EPOCH 102
# #################
# AVERAGE TRAIN LOSS: 0.2734209895133972
# AVERAGE VAL LOSS: 0.3799764811992645
# #################
# # EPOCH 103
# #################
# AVERAGE TRAIN LOSS: 0.2670813500881195
# AVERAGE VAL LOSS: 0.37291547656059265
# #################
# # EPOCH 104
# #################
# AVERAGE TRAIN LOSS: 0.26528578996658325
# AVERAGE VAL LOSS: 0.37198707461357117
# #################
# # EPOCH 105
# #################
# AVERAGE TRAIN LOSS: 0.27305346727371216
# AVERAGE VAL LOSS: 0.40330806374549866
# #################
# # EPOCH 106
# #################
# AVERAGE TRAIN LOSS: 0.25731801986694336
# AVERAGE VAL LOSS: 0.3902978003025055
# #################
# # EPOCH 107
# #################
# AVERAGE TRAIN LOSS: 0.2669442296028137
# AVERAGE VAL LOSS: 0.3813006579875946
# #################
# # EPOCH 108
# #################
# AVERAGE TRAIN LOSS: 0.2589194178581238
# AVERAGE VAL LOSS: 0.3697444498538971
# #################
# # EPOCH 109
# #################
# AVERAGE TRAIN LOSS: 0.2583200931549072
# AVERAGE VAL LOSS: 0.37531423568725586
# #################
# # EPOCH 110
# #################
# AVERAGE TRAIN LOSS: 0.2472313642501831
# AVERAGE VAL LOSS: 0.3633364140987396
# #################
# # EPOCH 111
# #################
# AVERAGE TRAIN LOSS: 0.25530537962913513
# AVERAGE VAL LOSS: 0.3586087226867676
# #################
# # EPOCH 112
# #################
# AVERAGE TRAIN LOSS: 0.2518324851989746
# AVERAGE VAL LOSS: 0.37644827365875244
# #################
# # EPOCH 113
# #################
# AVERAGE TRAIN LOSS: 0.25260791182518005
# AVERAGE VAL LOSS: 0.4242958426475525
# #################
# # EPOCH 114
# #################
# AVERAGE TRAIN LOSS: 0.2512218654155731
# AVERAGE VAL LOSS: 0.35778895020484924
# #################
# # EPOCH 115
# #################
# AVERAGE TRAIN LOSS: 0.248920276761055
# AVERAGE VAL LOSS: 0.35436758399009705
# #################
# # EPOCH 116
# #################
# AVERAGE TRAIN LOSS: 0.24538902938365936
# AVERAGE VAL LOSS: 0.36016666889190674
# #################
# # EPOCH 117
# #################
# AVERAGE TRAIN LOSS: 0.2540373206138611
# AVERAGE VAL LOSS: 0.40791335701942444
# #################
# # EPOCH 118
# #################
# AVERAGE TRAIN LOSS: 0.257180392742157
# AVERAGE VAL LOSS: 0.3888024091720581
# #################
# # EPOCH 119
# #################
# AVERAGE TRAIN LOSS: 0.24891293048858643
# AVERAGE VAL LOSS: 0.3943932354450226
# #################
# # EPOCH 120
# #################
# AVERAGE TRAIN LOSS: 0.25357455015182495
# AVERAGE VAL LOSS: 0.3664349317550659
# #################
# # EPOCH 121
# #################
# AVERAGE TRAIN LOSS: 0.24343173205852509
# AVERAGE VAL LOSS: 0.41735485196113586
# #################
# # EPOCH 122
# #################
# AVERAGE TRAIN LOSS: 0.2655926048755646
# AVERAGE VAL LOSS: 0.3928699791431427
# #################
# # EPOCH 123
# #################
# AVERAGE TRAIN LOSS: 0.23202724754810333
# AVERAGE VAL LOSS: 0.34638962149620056
# #################
# # EPOCH 124
# #################
# AVERAGE TRAIN LOSS: 0.22881266474723816
# AVERAGE VAL LOSS: 0.3465804159641266
# #################
# # EPOCH 125
# #################
# AVERAGE TRAIN LOSS: 0.2293652594089508
# AVERAGE VAL LOSS: 0.37335750460624695
# #################
# # EPOCH 126
# #################
# AVERAGE TRAIN LOSS: 0.22448234260082245
# AVERAGE VAL LOSS: 0.36215072870254517
# #################
# # EPOCH 127
# #################
# AVERAGE TRAIN LOSS: 0.22050146758556366
# AVERAGE VAL LOSS: 0.3420111835002899
# #################
# # EPOCH 128
# #################
# AVERAGE TRAIN LOSS: 0.21855930984020233
# AVERAGE VAL LOSS: 0.3449822664260864
# #################
# # EPOCH 129
# #################
# AVERAGE TRAIN LOSS: 0.22308644652366638
# AVERAGE VAL LOSS: 0.3579263985157013
# #################
# # EPOCH 130
# #################
# AVERAGE TRAIN LOSS: 0.22260412573814392
# AVERAGE VAL LOSS: 0.3558047413825989
# #################
# # EPOCH 131
# #################
# AVERAGE TRAIN LOSS: 0.22451241314411163
# AVERAGE VAL LOSS: 0.3522392809391022
# #################
# # EPOCH 132
# #################
# AVERAGE TRAIN LOSS: 0.23532482981681824
# AVERAGE VAL LOSS: 0.35092607140541077
# #################
# # EPOCH 133
# #################
# AVERAGE TRAIN LOSS: 0.23250141739845276
# AVERAGE VAL LOSS: 0.4233759641647339
# #################
# # EPOCH 134
# #################
# AVERAGE TRAIN LOSS: 0.2525372803211212
# AVERAGE VAL LOSS: 0.35639190673828125
# #################
# # EPOCH 135
# #################
# AVERAGE TRAIN LOSS: 0.2264663279056549
# AVERAGE VAL LOSS: 0.3393533229827881
# #################
# # EPOCH 136
# #################
# AVERAGE TRAIN LOSS: 0.21865668892860413
# AVERAGE VAL LOSS: 0.3267594873905182
# #################
# # EPOCH 137
# #################
# AVERAGE TRAIN LOSS: 0.21155604720115662
# AVERAGE VAL LOSS: 0.3767240047454834
# #################
# # EPOCH 138
# #################
# AVERAGE TRAIN LOSS: 0.2126549780368805
# AVERAGE VAL LOSS: 0.32941755652427673
# #################
# # EPOCH 139
# #################
# AVERAGE TRAIN LOSS: 0.21192750334739685
# AVERAGE VAL LOSS: 0.32846561074256897
# #################
# # EPOCH 140
# #################
# AVERAGE TRAIN LOSS: 0.20582225918769836
# AVERAGE VAL LOSS: 0.34790247678756714
# #################
# # EPOCH 141
# #################
# AVERAGE TRAIN LOSS: 0.2090030461549759
# AVERAGE VAL LOSS: 0.3524697422981262
# #################
# # EPOCH 142
# #################
# AVERAGE TRAIN LOSS: 0.20910851657390594
# AVERAGE VAL LOSS: 0.3200717866420746
# #################
# # EPOCH 143
# #################
# AVERAGE TRAIN LOSS: 0.19760535657405853
# AVERAGE VAL LOSS: 0.3243429362773895
# #################
# # EPOCH 144
# #################
# AVERAGE TRAIN LOSS: 0.19819697737693787
# AVERAGE VAL LOSS: 0.32977962493896484
# #################
# # EPOCH 145
# #################
# AVERAGE TRAIN LOSS: 0.21577830612659454
# AVERAGE VAL LOSS: 0.35230663418769836
# #################
# # EPOCH 146
# #################
# AVERAGE TRAIN LOSS: 0.21321964263916016
# AVERAGE VAL LOSS: 0.31653520464897156
# #################
# # EPOCH 147
# #################
# AVERAGE TRAIN LOSS: 0.21120032668113708
# AVERAGE VAL LOSS: 0.33349233865737915
# #################
# # EPOCH 148
# #################
# AVERAGE TRAIN LOSS: 0.21825361251831055
# AVERAGE VAL LOSS: 0.3307306468486786
# #################
# # EPOCH 149
# #################
# AVERAGE TRAIN LOSS: 0.19806215167045593
# AVERAGE VAL LOSS: 0.3172878921031952
# #################
# # EPOCH 150
# #################
# AVERAGE TRAIN LOSS: 0.18921391665935516
# AVERAGE VAL LOSS: 0.38160666823387146
# #################
# # EPOCH 151
# #################
# AVERAGE TRAIN LOSS: 0.21941177546977997
# AVERAGE VAL LOSS: 0.3656458854675293
# #################
# # EPOCH 152
# #################
# AVERAGE TRAIN LOSS: 0.2151123583316803
# AVERAGE VAL LOSS: 0.3512023091316223
# #################
# # EPOCH 153
# #################
# AVERAGE TRAIN LOSS: 0.21270231902599335
# AVERAGE VAL LOSS: 0.341703325510025
# #################
# # EPOCH 154
# #################
# AVERAGE TRAIN LOSS: 0.19659152626991272
# AVERAGE VAL LOSS: 0.33013591170310974
# #################
# # EPOCH 155
# #################
# AVERAGE TRAIN LOSS: 0.19497856497764587
# AVERAGE VAL LOSS: 0.3200185298919678
# #################
# # EPOCH 156
# #################
# AVERAGE TRAIN LOSS: 0.1995217204093933
# AVERAGE VAL LOSS: 0.3186659812927246
# #################
# # EPOCH 157
# #################
# AVERAGE TRAIN LOSS: 0.18765108287334442
# AVERAGE VAL LOSS: 0.3083294928073883
# #################
# # EPOCH 158
# #################
# AVERAGE TRAIN LOSS: 0.2005835324525833
# AVERAGE VAL LOSS: 0.3118843734264374
# #################
# # EPOCH 159
# #################
# AVERAGE TRAIN LOSS: 0.19080039858818054
# AVERAGE VAL LOSS: 0.36137062311172485
# #################
# # EPOCH 160
# #################
# AVERAGE TRAIN LOSS: 0.17979970574378967
# AVERAGE VAL LOSS: 0.2993129789829254
# #################
# # EPOCH 161
# #################
# AVERAGE TRAIN LOSS: 0.1819608360528946
# AVERAGE VAL LOSS: 0.2982405424118042
# #################
# # EPOCH 162
# #################
# AVERAGE TRAIN LOSS: 0.18343965709209442
# AVERAGE VAL LOSS: 0.3122594356536865
# #################
# # EPOCH 163
# #################
# AVERAGE TRAIN LOSS: 0.17556671798229218
# AVERAGE VAL LOSS: 0.3113025426864624
# #################
# # EPOCH 164
# #################
# AVERAGE TRAIN LOSS: 0.17841924726963043
# AVERAGE VAL LOSS: 0.30507755279541016
# #################
# # EPOCH 165
# #################
# AVERAGE TRAIN LOSS: 0.17423489689826965
# AVERAGE VAL LOSS: 0.31514644622802734
# #################
# # EPOCH 166
# #################
# AVERAGE TRAIN LOSS: 0.17991609871387482
# AVERAGE VAL LOSS: 0.3580397367477417
# #################
# # EPOCH 167
# #################
# AVERAGE TRAIN LOSS: 0.18042969703674316
# AVERAGE VAL LOSS: 0.3001657724380493
# #################
# # EPOCH 168
# #################
# AVERAGE TRAIN LOSS: 0.17408832907676697
# AVERAGE VAL LOSS: 0.2993371784687042
# #################
# # EPOCH 169
# #################
# AVERAGE TRAIN LOSS: 0.17812737822532654
# AVERAGE VAL LOSS: 0.29843786358833313
# #################
# # EPOCH 170
# #################
# AVERAGE TRAIN LOSS: 0.1661672294139862
# AVERAGE VAL LOSS: 0.31036195158958435
# #################
# # EPOCH 171
# #################
# AVERAGE TRAIN LOSS: 0.17586049437522888
# AVERAGE VAL LOSS: 0.39699846506118774
# #################
# # EPOCH 172
# #################
# AVERAGE TRAIN LOSS: 0.2343674898147583
# AVERAGE VAL LOSS: 0.3048408329486847
# #################
# # EPOCH 173
# #################
# AVERAGE TRAIN LOSS: 0.2019270658493042
# AVERAGE VAL LOSS: 0.30135378241539
# #################
# # EPOCH 174
# #################
# AVERAGE TRAIN LOSS: 0.171287402510643
# AVERAGE VAL LOSS: 0.3036709427833557
# #################
# # EPOCH 175
# #################
# AVERAGE TRAIN LOSS: 0.18521913886070251
# AVERAGE VAL LOSS: 0.3136345148086548
# #################
# # EPOCH 176
# #################
# AVERAGE TRAIN LOSS: 0.1778668314218521
# AVERAGE VAL LOSS: 0.32799848914146423
# #################
# # EPOCH 177
# #################
# AVERAGE TRAIN LOSS: 0.16997404396533966
# AVERAGE VAL LOSS: 0.3070056438446045
# #################
# # EPOCH 178
# #################
# AVERAGE TRAIN LOSS: 0.17311055958271027
# AVERAGE VAL LOSS: 0.2881561517715454
# #################
# # EPOCH 179
# #################
# AVERAGE TRAIN LOSS: 0.1628970354795456
# AVERAGE VAL LOSS: 0.30308741331100464
# #################
# # EPOCH 180
# #################
# AVERAGE TRAIN LOSS: 0.16011711955070496
# AVERAGE VAL LOSS: 0.29219919443130493
# #################
# # EPOCH 181
# #################
# AVERAGE TRAIN LOSS: 0.15981383621692657
# AVERAGE VAL LOSS: 0.28684306144714355
# #################
# # EPOCH 182
# #################
# AVERAGE TRAIN LOSS: 0.1754932403564453
# AVERAGE VAL LOSS: 0.29656410217285156
# #################
# # EPOCH 183
# #################
# AVERAGE TRAIN LOSS: 0.16643516719341278
# AVERAGE VAL LOSS: 0.3096729516983032
# #################
# # EPOCH 184
# #################
# AVERAGE TRAIN LOSS: 0.16176819801330566
# AVERAGE VAL LOSS: 0.2995011508464813
# #################
# # EPOCH 185
# #################
# AVERAGE TRAIN LOSS: 0.168142169713974
# AVERAGE VAL LOSS: 0.28306853771209717
# #################
# # EPOCH 186
# #################
# AVERAGE TRAIN LOSS: 0.16158150136470795
# AVERAGE VAL LOSS: 0.2937505543231964
# #################
# # EPOCH 187
# #################
# AVERAGE TRAIN LOSS: 0.1717870533466339
# AVERAGE VAL LOSS: 0.3249923586845398
# #################
# # EPOCH 188
# #################
# AVERAGE TRAIN LOSS: 0.1917438954114914
# AVERAGE VAL LOSS: 0.29902559518814087
# #################
# # EPOCH 189
# #################
# AVERAGE TRAIN LOSS: 0.17681781947612762
# AVERAGE VAL LOSS: 0.391398161649704
# #################
# # EPOCH 190
# #################
# AVERAGE TRAIN LOSS: 0.18367716670036316
# AVERAGE VAL LOSS: 0.29721808433532715
# #################
# # EPOCH 191
# #################
# AVERAGE TRAIN LOSS: 0.16783137619495392
# AVERAGE VAL LOSS: 0.29441162943840027
# #################
# # EPOCH 192
# #################
# AVERAGE TRAIN LOSS: 0.1615561544895172
# AVERAGE VAL LOSS: 0.3256833553314209
# #################
# # EPOCH 193
# #################
# AVERAGE TRAIN LOSS: 0.15983763337135315
# AVERAGE VAL LOSS: 0.2968166172504425
# #################
# # EPOCH 194
# #################
# AVERAGE TRAIN LOSS: 0.15958037972450256
# AVERAGE VAL LOSS: 0.2892630100250244
# #################
# # EPOCH 195
# #################
# AVERAGE TRAIN LOSS: 0.15585178136825562
# AVERAGE VAL LOSS: 0.290585994720459
# #################
# # EPOCH 196
# #################
# AVERAGE TRAIN LOSS: 0.1496012657880783
# AVERAGE VAL LOSS: 0.28574249148368835
# #################
# # EPOCH 197
# #################
# AVERAGE TRAIN LOSS: 0.14998197555541992
# AVERAGE VAL LOSS: 0.2774592638015747
# #################
# # EPOCH 198
# #################
# AVERAGE TRAIN LOSS: 0.1474398374557495
# AVERAGE VAL LOSS: 0.2841344177722931
# #################
# # EPOCH 199
# #################
# AVERAGE TRAIN LOSS: 0.14803557097911835
# AVERAGE VAL LOSS: 0.27751702070236206
# #################
# # EPOCH 200
# #################
# AVERAGE TRAIN LOSS: 0.1439041793346405
# AVERAGE VAL LOSS: 0.2806882858276367
# #################
# # EPOCH 201
# #################
# AVERAGE TRAIN LOSS: 0.14940492808818817
# AVERAGE VAL LOSS: 0.29149824380874634
# #################
# # EPOCH 202
# #################
# AVERAGE TRAIN LOSS: 0.15822255611419678
# AVERAGE VAL LOSS: 0.32219022512435913
# #################
# # EPOCH 203
# #################
# AVERAGE TRAIN LOSS: 0.15581730008125305
# AVERAGE VAL LOSS: 0.3264538645744324
# #################
# # EPOCH 204
# #################
# AVERAGE TRAIN LOSS: 0.1507377326488495
# AVERAGE VAL LOSS: 0.3379334509372711
# #################
# # EPOCH 205
# #################
# AVERAGE TRAIN LOSS: 0.15333130955696106
# AVERAGE VAL LOSS: 0.2885343134403229
# #################
# # EPOCH 206
# #################
# AVERAGE TRAIN LOSS: 0.1530350148677826
# AVERAGE VAL LOSS: 0.2895560562610626
# #################
# # EPOCH 207
# #################
# AVERAGE TRAIN LOSS: 0.14482834935188293
# AVERAGE VAL LOSS: 0.2773638665676117
# #################
# # EPOCH 208
# #################
# AVERAGE TRAIN LOSS: 0.14050893485546112
# AVERAGE VAL LOSS: 0.26474952697753906
# #################
# # EPOCH 209
# #################
# AVERAGE TRAIN LOSS: 0.13512150943279266
# AVERAGE VAL LOSS: 0.2716060280799866
# #################
# # EPOCH 210
# #################
# AVERAGE TRAIN LOSS: 0.14395837485790253
# AVERAGE VAL LOSS: 0.3291342556476593
# #################
# # EPOCH 211
# #################
# AVERAGE TRAIN LOSS: 0.15592536330223083
# AVERAGE VAL LOSS: 0.2740589380264282
# #################
# # EPOCH 212
# #################
# AVERAGE TRAIN LOSS: 0.15137775242328644
# AVERAGE VAL LOSS: 0.27432021498680115
# #################
# # EPOCH 213
# #################
# AVERAGE TRAIN LOSS: 0.14590007066726685
# AVERAGE VAL LOSS: 0.2842008173465729
# #################
# # EPOCH 214
# #################
# AVERAGE TRAIN LOSS: 0.1540190428495407
# AVERAGE VAL LOSS: 0.275296151638031
# #################
# # EPOCH 215
# #################
# AVERAGE TRAIN LOSS: 0.1444556713104248
# AVERAGE VAL LOSS: 0.32907697558403015
# #################
# # EPOCH 216
# #################
# AVERAGE TRAIN LOSS: 0.15293946862220764
# AVERAGE VAL LOSS: 0.2950316071510315
# #################
# # EPOCH 217
# #################
# AVERAGE TRAIN LOSS: 0.16065660119056702
# AVERAGE VAL LOSS: 0.27890506386756897
# #################
# # EPOCH 218
# #################
# AVERAGE TRAIN LOSS: 0.14005973935127258
# AVERAGE VAL LOSS: 0.29039207100868225
# #################
# # EPOCH 219
# #################
# AVERAGE TRAIN LOSS: 0.14695774018764496
# AVERAGE VAL LOSS: 0.27847760915756226
# #################
# # EPOCH 220
# #################
# AVERAGE TRAIN LOSS: 0.16061656177043915
# AVERAGE VAL LOSS: 0.27709710597991943
# #################
# # EPOCH 221
# #################
# AVERAGE TRAIN LOSS: 0.14553846418857574
# AVERAGE VAL LOSS: 0.2761825621128082
# #################
# # EPOCH 222
# #################
# AVERAGE TRAIN LOSS: 0.15152165293693542
# AVERAGE VAL LOSS: 0.2790485918521881
# #################
# # EPOCH 223
# #################
# AVERAGE TRAIN LOSS: 0.15757611393928528
# AVERAGE VAL LOSS: 0.3455733358860016
# #################
# # EPOCH 224
# #################
# AVERAGE TRAIN LOSS: 0.16357597708702087
# AVERAGE VAL LOSS: 0.2737636864185333
# #################
# # EPOCH 225
# #################
# AVERAGE TRAIN LOSS: 0.1489286720752716
# AVERAGE VAL LOSS: 0.28484049439430237
# #################
# # EPOCH 226
# #################
# AVERAGE TRAIN LOSS: 0.13966482877731323
# AVERAGE VAL LOSS: 0.2792637050151825
# #################
# # EPOCH 227
# #################
# AVERAGE TRAIN LOSS: 0.14123865962028503
# AVERAGE VAL LOSS: 0.2762572765350342
# #################
# # EPOCH 228
# #################
# AVERAGE TRAIN LOSS: 0.1373879760503769
# AVERAGE VAL LOSS: 0.2847837805747986
# #################
# # EPOCH 229
# #################
# AVERAGE TRAIN LOSS: 0.13638222217559814
# AVERAGE VAL LOSS: 0.2607189118862152
# #################
# # EPOCH 230
# #################
# AVERAGE TRAIN LOSS: 0.12953032553195953
# AVERAGE VAL LOSS: 0.2671007215976715
# #################
# # EPOCH 231
# #################
# AVERAGE TRAIN LOSS: 0.12955936789512634
# AVERAGE VAL LOSS: 0.28747978806495667
# #################
# # EPOCH 232
# #################
# AVERAGE TRAIN LOSS: 0.14811015129089355
# AVERAGE VAL LOSS: 0.32264721393585205
# #################
# # EPOCH 233
# #################
# AVERAGE TRAIN LOSS: 0.14595109224319458
# AVERAGE VAL LOSS: 0.3081294298171997
# #################
# # EPOCH 234
# #################
# AVERAGE TRAIN LOSS: 0.16098232567310333
# AVERAGE VAL LOSS: 0.26808518171310425
# #################
# # EPOCH 235
# #################
# AVERAGE TRAIN LOSS: 0.14892423152923584
# AVERAGE VAL LOSS: 0.31873130798339844
# #################
# # EPOCH 236
# #################
# AVERAGE TRAIN LOSS: 0.14607465267181396
# AVERAGE VAL LOSS: 0.2686830461025238
# #################
# # EPOCH 237
# #################
# AVERAGE TRAIN LOSS: 0.15123005211353302
# AVERAGE VAL LOSS: 0.3220211863517761
# #################
# # EPOCH 238
# #################
# AVERAGE TRAIN LOSS: 0.1669270098209381
# AVERAGE VAL LOSS: 0.32821735739707947
# #################
# # EPOCH 239
# #################
# AVERAGE TRAIN LOSS: 0.15755248069763184
# AVERAGE VAL LOSS: 0.32679298520088196
# #################
# # EPOCH 240
# #################
# AVERAGE TRAIN LOSS: 0.16942906379699707
# AVERAGE VAL LOSS: 0.3246355652809143
# #################
# # EPOCH 241
# #################
# AVERAGE TRAIN LOSS: 0.16945931315422058
# AVERAGE VAL LOSS: 0.31153604388237
# #################
# # EPOCH 242
# #################
# AVERAGE TRAIN LOSS: 0.16018734872341156
# AVERAGE VAL LOSS: 0.38388389348983765
# #################
# # EPOCH 243
# #################
# AVERAGE TRAIN LOSS: 0.16664133965969086
# AVERAGE VAL LOSS: 0.30597978830337524
# #################
# # EPOCH 244
# #################
# AVERAGE TRAIN LOSS: 0.1472751498222351
# AVERAGE VAL LOSS: 0.28132790327072144
# #################
# # EPOCH 245
# #################
# AVERAGE TRAIN LOSS: 0.13016614317893982
# AVERAGE VAL LOSS: 0.26733916997909546
# #################
# # EPOCH 246
# #################
# AVERAGE TRAIN LOSS: 0.133183091878891
# AVERAGE VAL LOSS: 0.2790568172931671
# #################
# # EPOCH 247
# #################
# AVERAGE TRAIN LOSS: 0.13364794850349426
# AVERAGE VAL LOSS: 0.26407602429389954
# #################
# # EPOCH 248
# #################
# AVERAGE TRAIN LOSS: 0.12539827823638916
# AVERAGE VAL LOSS: 0.267345130443573
# #################
# # EPOCH 249
# #################
# AVERAGE TRAIN LOSS: 0.1222987174987793
# AVERAGE VAL LOSS: 0.253195196390152
# #################
# # EPOCH 250
# #################
# AVERAGE TRAIN LOSS: 0.12143677473068237
# AVERAGE VAL LOSS: 0.25993314385414124
# #################
# # EPOCH 251
# #################
# AVERAGE TRAIN LOSS: 0.12127380073070526
# AVERAGE VAL LOSS: 0.2503131031990051
# #################
# # EPOCH 252
# #################
# AVERAGE TRAIN LOSS: 0.12169057130813599
# AVERAGE VAL LOSS: 0.24901244044303894
# #################
# # EPOCH 253
# #################
# AVERAGE TRAIN LOSS: 0.1287313997745514
# AVERAGE VAL LOSS: 0.27628093957901
# #################
# # EPOCH 254
# #################
# AVERAGE TRAIN LOSS: 0.12310435622930527
# AVERAGE VAL LOSS: 0.2527386546134949
# #################
# # EPOCH 255
# #################
# AVERAGE TRAIN LOSS: 0.12108508497476578
# AVERAGE VAL LOSS: 0.2553406357765198
# #################
# # EPOCH 256
# #################
# AVERAGE TRAIN LOSS: 0.12342369556427002
# AVERAGE VAL LOSS: 0.2837512791156769
# #################
# # EPOCH 257
# #################
# AVERAGE TRAIN LOSS: 0.1307435929775238
# AVERAGE VAL LOSS: 0.2684469223022461
# #################
# # EPOCH 258
# #################
# AVERAGE TRAIN LOSS: 0.12776832282543182
# AVERAGE VAL LOSS: 0.2676681876182556
# #################
# # EPOCH 259
# #################
# AVERAGE TRAIN LOSS: 0.12133613973855972
# AVERAGE VAL LOSS: 0.25495225191116333
# #################
# # EPOCH 260
# #################
# AVERAGE TRAIN LOSS: 0.12487965822219849
# AVERAGE VAL LOSS: 0.2533751130104065
# #################
# # EPOCH 261
# #################
# AVERAGE TRAIN LOSS: 0.12335659563541412
# AVERAGE VAL LOSS: 0.26839330792427063
# #################
# # EPOCH 262
# #################
# AVERAGE TRAIN LOSS: 0.11848368495702744
# AVERAGE VAL LOSS: 0.265785813331604
# #################
# # EPOCH 263
# #################
# AVERAGE TRAIN LOSS: 0.12133391946554184
# AVERAGE VAL LOSS: 0.2714376449584961
# #################
# # EPOCH 264
# #################
# AVERAGE TRAIN LOSS: 0.12027981132268906
# AVERAGE VAL LOSS: 0.25500431656837463
# #################
# # EPOCH 265
# #################
# AVERAGE TRAIN LOSS: 0.12035533040761948
# AVERAGE VAL LOSS: 0.2808883488178253
# #################
# # EPOCH 266
# #################
# AVERAGE TRAIN LOSS: 0.12273956835269928
# AVERAGE VAL LOSS: 0.25668951869010925
# #################
# # EPOCH 267
# #################
# AVERAGE TRAIN LOSS: 0.11911284923553467
# AVERAGE VAL LOSS: 0.27424106001853943
# #################
# # EPOCH 268
# #################
# AVERAGE TRAIN LOSS: 0.1225544810295105
# AVERAGE VAL LOSS: 0.2686173915863037
# #################
# # EPOCH 269
# #################
# AVERAGE TRAIN LOSS: 0.12654998898506165
# AVERAGE VAL LOSS: 0.2778759002685547
# #################
# # EPOCH 270
# #################
# AVERAGE TRAIN LOSS: 0.1275796890258789
# AVERAGE VAL LOSS: 0.2691492438316345
# #################
# # EPOCH 271
# #################
# AVERAGE TRAIN LOSS: 0.12057344615459442
# AVERAGE VAL LOSS: 0.2724752128124237
# #################
# # EPOCH 272
# #################
# AVERAGE TRAIN LOSS: 0.12506254017353058
# AVERAGE VAL LOSS: 0.2541244924068451
# #################
# # EPOCH 273
# #################
# AVERAGE TRAIN LOSS: 0.11491724103689194
# AVERAGE VAL LOSS: 0.25498509407043457
# #################
# # EPOCH 274
# #################
# AVERAGE TRAIN LOSS: 0.12148720026016235
# AVERAGE VAL LOSS: 0.24490605294704437
# #################
# # EPOCH 275
# #################
# AVERAGE TRAIN LOSS: 0.1218014806509018
# AVERAGE VAL LOSS: 0.2572697401046753
# #################
# # EPOCH 276
# #################
# AVERAGE TRAIN LOSS: 0.1158994808793068
# AVERAGE VAL LOSS: 0.25897419452667236
# #################
# # EPOCH 277
# #################
# AVERAGE TRAIN LOSS: 0.11379703134298325
# AVERAGE VAL LOSS: 0.2843291759490967
# #################
# # EPOCH 278
# #################
# AVERAGE TRAIN LOSS: 0.11783850193023682
# AVERAGE VAL LOSS: 0.24682185053825378
# #################
# # EPOCH 279
# #################
# AVERAGE TRAIN LOSS: 0.11675696074962616
# AVERAGE VAL LOSS: 0.25649839639663696
# #################
# # EPOCH 280
# #################
# AVERAGE TRAIN LOSS: 0.11209289729595184
# AVERAGE VAL LOSS: 0.2619984745979309
# #################
# # EPOCH 281
# #################
# AVERAGE TRAIN LOSS: 0.11816829442977905
# AVERAGE VAL LOSS: 0.2700987458229065
# #################
# # EPOCH 282
# #################
# AVERAGE TRAIN LOSS: 0.11455366760492325
# AVERAGE VAL LOSS: 0.26371780037879944
# #################
# # EPOCH 283
# #################
# AVERAGE TRAIN LOSS: 0.11574367433786392
# AVERAGE VAL LOSS: 0.26088669896125793
# #################
# # EPOCH 284
# #################
# AVERAGE TRAIN LOSS: 0.10949186235666275
# AVERAGE VAL LOSS: 0.2571414113044739
# #################
# # EPOCH 285
# #################
# AVERAGE TRAIN LOSS: 0.11810798943042755
# AVERAGE VAL LOSS: 0.24307338893413544
# #################
# # EPOCH 286
# #################
# AVERAGE TRAIN LOSS: 0.1067960262298584
# AVERAGE VAL LOSS: 0.24625609815120697
# #################
# # EPOCH 287
# #################
# AVERAGE TRAIN LOSS: 0.10918883979320526
# AVERAGE VAL LOSS: 0.26162901520729065
# #################
# # EPOCH 288
# #################
# AVERAGE TRAIN LOSS: 0.10451004654169083
# AVERAGE VAL LOSS: 0.23996314406394958
# #################
# # EPOCH 289
# #################
# AVERAGE TRAIN LOSS: 0.1119556874036789
# AVERAGE VAL LOSS: 0.2572843134403229
# #################
# # EPOCH 290
# #################
# AVERAGE TRAIN LOSS: 0.11306558549404144
# AVERAGE VAL LOSS: 0.25193363428115845
# #################
# # EPOCH 291
# #################
# AVERAGE TRAIN LOSS: 0.11783552169799805
# AVERAGE VAL LOSS: 0.2756271958351135
# #################
# # EPOCH 292
# #################
# AVERAGE TRAIN LOSS: 0.13349196314811707
# AVERAGE VAL LOSS: 0.37395110726356506
# #################
# # EPOCH 293
# #################
# AVERAGE TRAIN LOSS: 0.17226189374923706
# AVERAGE VAL LOSS: 0.30630484223365784
# #################
# # EPOCH 294
# #################
# AVERAGE TRAIN LOSS: 0.15089814364910126
# AVERAGE VAL LOSS: 0.3815467357635498
# #################
# # EPOCH 295
# #################
# AVERAGE TRAIN LOSS: 0.1525331437587738
# AVERAGE VAL LOSS: 0.3107486069202423
# #################
# # EPOCH 296
# #################
# AVERAGE TRAIN LOSS: 0.12822945415973663
# AVERAGE VAL LOSS: 0.30169105529785156
# #################
# # EPOCH 297
# #################
# AVERAGE TRAIN LOSS: 0.1263940930366516
# AVERAGE VAL LOSS: 0.27562782168388367
# #################
# # EPOCH 298
# #################
# AVERAGE TRAIN LOSS: 0.1256313920021057
# AVERAGE VAL LOSS: 0.2678734064102173
# #################
# # EPOCH 299
# #################
# AVERAGE TRAIN LOSS: 0.1170203909277916
# AVERAGE VAL LOSS: 0.2759029269218445
# #################
# # EPOCH 300
# #################
# AVERAGE TRAIN LOSS: 0.10807661712169647
# AVERAGE VAL LOSS: 0.24680328369140625
# #################
# # EPOCH 301
# #################
# AVERAGE TRAIN LOSS: 0.10326002538204193
# AVERAGE VAL LOSS: 0.2516414225101471
# #################
# # EPOCH 302
# #################
# AVERAGE TRAIN LOSS: 0.10590746253728867
# AVERAGE VAL LOSS: 0.24901501834392548
# #################
# # EPOCH 303
# #################
# AVERAGE TRAIN LOSS: 0.1058390736579895
# AVERAGE VAL LOSS: 0.2482372373342514
# #################
# # EPOCH 304
# #################
# AVERAGE TRAIN LOSS: 0.10405466705560684
# AVERAGE VAL LOSS: 0.24523422122001648
# #################
# # EPOCH 305
# #################
# AVERAGE TRAIN LOSS: 0.10285066068172455
# AVERAGE VAL LOSS: 0.24398978054523468
# #################
# # EPOCH 306
# #################
# AVERAGE TRAIN LOSS: 0.10571630299091339
# AVERAGE VAL LOSS: 0.2583862543106079
# #################
# # EPOCH 307
# #################
# AVERAGE TRAIN LOSS: 0.11796321719884872
# AVERAGE VAL LOSS: 0.24042846262454987
# #################
# # EPOCH 308
# #################
# AVERAGE TRAIN LOSS: 0.09902249276638031
# AVERAGE VAL LOSS: 0.24983198940753937
# #################
# # EPOCH 309
# #################
# AVERAGE TRAIN LOSS: 0.11400236934423447
# AVERAGE VAL LOSS: 0.26794853806495667
# #################
# # EPOCH 310
# #################
# AVERAGE TRAIN LOSS: 0.12038910388946533
# AVERAGE VAL LOSS: 0.23775680363178253
# #################
# # EPOCH 311
# #################
# AVERAGE TRAIN LOSS: 0.09902358055114746
# AVERAGE VAL LOSS: 0.24663245677947998
# #################
# # EPOCH 312
# #################
# AVERAGE TRAIN LOSS: 0.10345768928527832
# AVERAGE VAL LOSS: 0.23291316628456116
# #################
# # EPOCH 313
# #################
# AVERAGE TRAIN LOSS: 0.10315315425395966
# AVERAGE VAL LOSS: 0.24104724824428558
# #################
# # EPOCH 314
# #################
# AVERAGE TRAIN LOSS: 0.09945381432771683
# AVERAGE VAL LOSS: 0.23068320751190186
# #################
# # EPOCH 315
# #################
# AVERAGE TRAIN LOSS: 0.09954960644245148
# AVERAGE VAL LOSS: 0.24169372022151947
# #################
# # EPOCH 316
# #################
# AVERAGE TRAIN LOSS: 0.09949550032615662
# AVERAGE VAL LOSS: 0.23650182783603668
# #################
# # EPOCH 317
# #################
# AVERAGE TRAIN LOSS: 0.10919288545846939
# AVERAGE VAL LOSS: 0.26864367723464966
# #################
# # EPOCH 318
# #################
# AVERAGE TRAIN LOSS: 0.11320281028747559
# AVERAGE VAL LOSS: 0.2685951888561249
# #################
# # EPOCH 319
# #################
# AVERAGE TRAIN LOSS: 0.1025763601064682
# AVERAGE VAL LOSS: 0.24122776091098785
# #################
# # EPOCH 320
# #################
# AVERAGE TRAIN LOSS: 0.09741596132516861
# AVERAGE VAL LOSS: 0.23975825309753418
# #################
# # EPOCH 321
# #################
# AVERAGE TRAIN LOSS: 0.09691403806209564
# AVERAGE VAL LOSS: 0.2504793107509613
# #################
# # EPOCH 322
# #################
# AVERAGE TRAIN LOSS: 0.10271032154560089
# AVERAGE VAL LOSS: 0.24554869532585144
# #################
# # EPOCH 323
# #################
# AVERAGE TRAIN LOSS: 0.10444168746471405
# AVERAGE VAL LOSS: 0.23987391591072083
# #################
# # EPOCH 324
# #################
# AVERAGE TRAIN LOSS: 0.10261797904968262
# AVERAGE VAL LOSS: 0.23932962119579315
# #################
# # EPOCH 325
# #################
# AVERAGE TRAIN LOSS: 0.10817314684391022
# AVERAGE VAL LOSS: 0.2502932846546173
# #################
# # EPOCH 326
# #################
# AVERAGE TRAIN LOSS: 0.1026202067732811
# AVERAGE VAL LOSS: 0.23177626729011536
# #################
# # EPOCH 327
# #################
# AVERAGE TRAIN LOSS: 0.0996585488319397
# AVERAGE VAL LOSS: 0.24145378172397614
# #################
# # EPOCH 328
# #################
# AVERAGE TRAIN LOSS: 0.09669705480337143
# AVERAGE VAL LOSS: 0.24037644267082214
# #################
# # EPOCH 329
# #################
# AVERAGE TRAIN LOSS: 0.09227345883846283
# AVERAGE VAL LOSS: 0.22841975092887878
# #################
# # EPOCH 330
# #################
# AVERAGE TRAIN LOSS: 0.09848465770483017
# AVERAGE VAL LOSS: 0.24208715558052063
# #################
# # EPOCH 331
# #################
# AVERAGE TRAIN LOSS: 0.0988064557313919
# AVERAGE VAL LOSS: 0.2614821493625641
# #################
# # EPOCH 332
# #################
# AVERAGE TRAIN LOSS: 0.10143090784549713
# AVERAGE VAL LOSS: 0.2443428933620453
# #################
# # EPOCH 333
# #################
# AVERAGE TRAIN LOSS: 0.09465695917606354
# AVERAGE VAL LOSS: 0.22531642019748688
# #################
# # EPOCH 334
# #################
# AVERAGE TRAIN LOSS: 0.09000489860773087
# AVERAGE VAL LOSS: 0.2265879511833191
# #################
# # EPOCH 335
# #################
# AVERAGE TRAIN LOSS: 0.09081768244504929
# AVERAGE VAL LOSS: 0.22785162925720215
# #################
# # EPOCH 336
# #################
# AVERAGE TRAIN LOSS: 0.09353955835103989
# AVERAGE VAL LOSS: 0.24177901446819305
# #################
# # EPOCH 337
# #################
# AVERAGE TRAIN LOSS: 0.09031152725219727
# AVERAGE VAL LOSS: 0.226979061961174
# #################
# # EPOCH 338
# #################
# AVERAGE TRAIN LOSS: 0.09319660067558289
# AVERAGE VAL LOSS: 0.2260657101869583
# #################
# # EPOCH 339
# #################
# AVERAGE TRAIN LOSS: 0.09246735274791718
# AVERAGE VAL LOSS: 0.2372027337551117
# #################
# # EPOCH 340
# #################
# AVERAGE TRAIN LOSS: 0.09045879542827606
# AVERAGE VAL LOSS: 0.23110350966453552
# #################
# # EPOCH 341
# #################
# AVERAGE TRAIN LOSS: 0.08835361897945404
# AVERAGE VAL LOSS: 0.22339844703674316
# #################
# # EPOCH 342
# #################
# AVERAGE TRAIN LOSS: 0.08799801021814346
# AVERAGE VAL LOSS: 0.23120322823524475
# #################
# # EPOCH 343
# #################
# AVERAGE TRAIN LOSS: 0.09372616559267044
# AVERAGE VAL LOSS: 0.23724423348903656
# #################
# # EPOCH 344
# #################
# AVERAGE TRAIN LOSS: 0.09680897742509842
# AVERAGE VAL LOSS: 0.2284291386604309
# #################
# # EPOCH 345
# #################
# AVERAGE TRAIN LOSS: 0.08839593082666397
# AVERAGE VAL LOSS: 0.2306515872478485
# #################
# # EPOCH 346
# #################
# AVERAGE TRAIN LOSS: 0.09162341058254242
# AVERAGE VAL LOSS: 0.2390073537826538
# #################
# # EPOCH 347
# #################
# AVERAGE TRAIN LOSS: 0.08934067189693451
# AVERAGE VAL LOSS: 0.25485044717788696
# #################
# # EPOCH 348
# #################
# AVERAGE TRAIN LOSS: 0.09615951031446457
# AVERAGE VAL LOSS: 0.2171778380870819
# #################
# # EPOCH 349
# #################
# AVERAGE TRAIN LOSS: 0.08611376583576202
# AVERAGE VAL LOSS: 0.21716195344924927
# #################
# # EPOCH 350
# #################
# AVERAGE TRAIN LOSS: 0.08869443833827972
# AVERAGE VAL LOSS: 0.23469260334968567
# #################
# # EPOCH 351
# #################
# AVERAGE TRAIN LOSS: 0.10018908977508545
# AVERAGE VAL LOSS: 0.2353460043668747
# #################
# # EPOCH 352
# #################
# AVERAGE TRAIN LOSS: 0.09245409071445465
# AVERAGE VAL LOSS: 0.21392424404621124
# #################
# # EPOCH 353
# #################
# AVERAGE TRAIN LOSS: 0.090756356716156
# AVERAGE VAL LOSS: 0.22905445098876953
# #################
# # EPOCH 354
# #################
# AVERAGE TRAIN LOSS: 0.08740764856338501
# AVERAGE VAL LOSS: 0.24929790198802948
# #################
# # EPOCH 355
# #################
# AVERAGE TRAIN LOSS: 0.09167591482400894
# AVERAGE VAL LOSS: 0.2146061658859253
# #################
# # EPOCH 356
# #################
# AVERAGE TRAIN LOSS: 0.0926990956068039
# AVERAGE VAL LOSS: 0.22771300375461578
# #################
# # EPOCH 357
# #################
# AVERAGE TRAIN LOSS: 0.10078220069408417
# AVERAGE VAL LOSS: 0.2288137823343277
# #################
# # EPOCH 358
# #################
# AVERAGE TRAIN LOSS: 0.11442216485738754
# AVERAGE VAL LOSS: 0.2617349624633789
# #################
# # EPOCH 359
# #################
# AVERAGE TRAIN LOSS: 0.10340572893619537
# AVERAGE VAL LOSS: 0.26965978741645813
# #################
# # EPOCH 360
# #################
# AVERAGE TRAIN LOSS: 0.10040527582168579
# AVERAGE VAL LOSS: 0.27039486169815063
# #################
# # EPOCH 361
# #################
# AVERAGE TRAIN LOSS: 0.0910983756184578
# AVERAGE VAL LOSS: 0.22610072791576385
# #################
# # EPOCH 362
# #################
# AVERAGE TRAIN LOSS: 0.09107573330402374
# AVERAGE VAL LOSS: 0.22165866196155548
# #################
# # EPOCH 363
# #################
# AVERAGE TRAIN LOSS: 0.08900892734527588
# AVERAGE VAL LOSS: 0.2373260110616684
# #################
# # EPOCH 364
# #################
# AVERAGE TRAIN LOSS: 0.08943066745996475
# AVERAGE VAL LOSS: 0.23105330765247345
# #################
# # EPOCH 365
# #################
# AVERAGE TRAIN LOSS: 0.0851084440946579
# AVERAGE VAL LOSS: 0.21201394498348236
# #################
# # EPOCH 366
# #################
# AVERAGE TRAIN LOSS: 0.08555283397436142
# AVERAGE VAL LOSS: 0.22538192570209503
# #################
# # EPOCH 367
# #################
# AVERAGE TRAIN LOSS: 0.08902747184038162
# AVERAGE VAL LOSS: 0.24732522666454315
# #################
# # EPOCH 368
# #################
# AVERAGE TRAIN LOSS: 0.08549705892801285
# AVERAGE VAL LOSS: 0.228886678814888
# #################
# # EPOCH 369
# #################
# AVERAGE TRAIN LOSS: 0.08837715536355972
# AVERAGE VAL LOSS: 0.24837061762809753
# #################
# # EPOCH 370
# #################
# AVERAGE TRAIN LOSS: 0.09416082501411438
# AVERAGE VAL LOSS: 0.22152015566825867
# #################
# # EPOCH 371
# #################
# AVERAGE TRAIN LOSS: 0.09403269737958908
# AVERAGE VAL LOSS: 0.23264312744140625
# #################
# # EPOCH 372
# #################
# AVERAGE TRAIN LOSS: 0.09251275658607483
# AVERAGE VAL LOSS: 0.21834556758403778
# #################
# # EPOCH 373
# #################
# AVERAGE TRAIN LOSS: 0.08125117421150208
# AVERAGE VAL LOSS: 0.2258131355047226
# #################
# # EPOCH 374
# #################
# AVERAGE TRAIN LOSS: 0.0802232176065445
# AVERAGE VAL LOSS: 0.22102214395999908
# #################
# # EPOCH 375
# #################
# AVERAGE TRAIN LOSS: 0.08197108656167984
# AVERAGE VAL LOSS: 0.2155514806509018
# #################
# # EPOCH 376
# #################
# AVERAGE TRAIN LOSS: 0.07795676589012146
# AVERAGE VAL LOSS: 0.21253669261932373
# #################
# # EPOCH 377
# #################
# AVERAGE TRAIN LOSS: 0.0795549750328064
# AVERAGE VAL LOSS: 0.23340167105197906
# #################
# # EPOCH 378
# #################
# AVERAGE TRAIN LOSS: 0.08548612147569656
# AVERAGE VAL LOSS: 0.22052323818206787
# #################
# # EPOCH 379
# #################
# AVERAGE TRAIN LOSS: 0.08578412234783173
# AVERAGE VAL LOSS: 0.23393075168132782
# #################
# # EPOCH 380
# #################
# AVERAGE TRAIN LOSS: 0.08024947345256805
# AVERAGE VAL LOSS: 0.22349852323532104
# #################
# # EPOCH 381
# #################
# AVERAGE TRAIN LOSS: 0.0766369104385376
# AVERAGE VAL LOSS: 0.21687163412570953
# #################
# # EPOCH 382
# #################
# AVERAGE TRAIN LOSS: 0.08078274875879288
# AVERAGE VAL LOSS: 0.23556533455848694
# #################
# # EPOCH 383
# #################
# AVERAGE TRAIN LOSS: 0.08256231248378754
# AVERAGE VAL LOSS: 0.21912017464637756
# #################
# # EPOCH 384
# #################
# AVERAGE TRAIN LOSS: 0.08040829747915268
# ...
# AVERAGE VAL LOSS: 0.22335053980350494
# #################
# # EPOCH 473
# #################
# AVERAGE TRAIN LOSS: 0.06827713549137115
# AVERAGE VAL LOSS: 0.23597045242786407
# #################
# # EPOCH 474
# #################
# AVERAGE TRAIN LOSS: 0.07191554456949234
# AVERAGE VAL LOSS: 0.23389498889446259
# #################
# # EPOCH 475
# #################
# AVERAGE TRAIN LOSS: 0.07675719261169434
# AVERAGE VAL LOSS: 0.23173080384731293
# #################
# # EPOCH 476
# #################
# AVERAGE TRAIN LOSS: 0.07016842067241669
# AVERAGE VAL LOSS: 0.21976466476917267
# #################
# # EPOCH 477
# #################
# AVERAGE TRAIN LOSS: 0.06558116525411606
# AVERAGE VAL LOSS: 0.23425033688545227
# #################
# # EPOCH 478
# #################
# AVERAGE TRAIN LOSS: 0.06566749513149261
# AVERAGE VAL LOSS: 0.23043030500411987
# #################
# # EPOCH 479
# #################
# AVERAGE TRAIN LOSS: 0.06407858431339264
# AVERAGE VAL LOSS: 0.24906516075134277
# #################
# # EPOCH 480
# #################
# AVERAGE TRAIN LOSS: 0.06544814258813858
# AVERAGE VAL LOSS: 0.2415134310722351
# #################
# # EPOCH 481
# #################
# AVERAGE TRAIN LOSS: 0.06451260298490524
# AVERAGE VAL LOSS: 0.22821977734565735
# #################
# # EPOCH 482
# #################
# AVERAGE TRAIN LOSS: 0.06443066895008087
# AVERAGE VAL LOSS: 0.21796393394470215
# #################
# # EPOCH 483
# #################
# AVERAGE TRAIN LOSS: 0.0646737590432167
# AVERAGE VAL LOSS: 0.23311331868171692
# #################
# # EPOCH 484
# #################
# AVERAGE TRAIN LOSS: 0.07172693312168121
# AVERAGE VAL LOSS: 0.23382370173931122
# #################
# # EPOCH 485
# #################
# AVERAGE TRAIN LOSS: 0.06975559890270233
# AVERAGE VAL LOSS: 0.2184401899576187
# #################
# # EPOCH 486
# #################
# AVERAGE TRAIN LOSS: 0.06344980746507645
# AVERAGE VAL LOSS: 0.22088204324245453
# #################
# # EPOCH 487
# #################
# AVERAGE TRAIN LOSS: 0.06568585336208344
# AVERAGE VAL LOSS: 0.22100238502025604
# #################
# # EPOCH 488
# #################
# AVERAGE TRAIN LOSS: 0.06128307059407234
# AVERAGE VAL LOSS: 0.22420348227024078
# #################
# # EPOCH 489
# #################
# AVERAGE TRAIN LOSS: 0.059987872838974
# AVERAGE VAL LOSS: 0.21904107928276062
# #################
# # EPOCH 490
# #################
# AVERAGE TRAIN LOSS: 0.0613909475505352
# AVERAGE VAL LOSS: 0.2104608416557312
# #################
# # EPOCH 491
# #################
# AVERAGE TRAIN LOSS: 0.06809190660715103
# AVERAGE VAL LOSS: 0.24817432463169098
# #################
# # EPOCH 492
# #################
# AVERAGE TRAIN LOSS: 0.07464675605297089
# AVERAGE VAL LOSS: 0.2357749193906784
# #################
# # EPOCH 493
# #################
# AVERAGE TRAIN LOSS: 0.07348126173019409
# AVERAGE VAL LOSS: 0.22469528019428253
# #################
# # EPOCH 494
# #################
# AVERAGE TRAIN LOSS: 0.06430082023143768
# AVERAGE VAL LOSS: 0.2412751466035843
# #################
# # EPOCH 495
# #################
# AVERAGE TRAIN LOSS: 0.06959668546915054
# AVERAGE VAL LOSS: 0.2322966754436493
# #################
# # EPOCH 496
# #################
# AVERAGE TRAIN LOSS: 0.06762667745351791
# AVERAGE VAL LOSS: 0.21697448194026947
# #################
# # EPOCH 497
# #################
# AVERAGE TRAIN LOSS: 0.0646914541721344
# AVERAGE VAL LOSS: 0.21857762336730957
# #################
# # EPOCH 498
# #################
# AVERAGE TRAIN LOSS: 0.05903076007962227
# AVERAGE VAL LOSS: 0.21680520474910736
# #################
# # EPOCH 499
# #################
# AVERAGE TRAIN LOSS: 0.059135802090168
# AVERAGE VAL LOSS: 0.21916277706623077
# #################
# # EPOCH 500
# #################
# AVERAGE TRAIN LOSS: 0.06169445067644119
# AVERAGE VAL LOSS: 0.21614617109298706
# #################
# # EPOCH 501
# #################
# AVERAGE TRAIN LOSS: 0.06426068395376205
# AVERAGE VAL LOSS: 0.2267743945121765
# #################
# # EPOCH 502
# #################
# AVERAGE TRAIN LOSS: 0.0644511952996254
# AVERAGE VAL LOSS: 0.2225610315799713
# #################
# # EPOCH 503
# #################
# AVERAGE TRAIN LOSS: 0.055644214153289795
# AVERAGE VAL LOSS: 0.2099524289369583
# #################
# # EPOCH 504
# #################
# AVERAGE TRAIN LOSS: 0.057387907058000565
# AVERAGE VAL LOSS: 0.22303660213947296
# #################
# # EPOCH 505
# #################
# AVERAGE TRAIN LOSS: 0.06164029240608215
# AVERAGE VAL LOSS: 0.22026990354061127
# #################
# # EPOCH 506
# #################
# AVERAGE TRAIN LOSS: 0.06923422962427139
# AVERAGE VAL LOSS: 0.23507782816886902
# #################
# # EPOCH 507
# #################
# AVERAGE TRAIN LOSS: 0.05765427276492119
# AVERAGE VAL LOSS: 0.2367423176765442
# #################
# # EPOCH 508
# #################
# AVERAGE TRAIN LOSS: 0.06704486906528473
# AVERAGE VAL LOSS: 0.2216980755329132
# #################
# # EPOCH 509
# #################
# AVERAGE TRAIN LOSS: 0.05615592747926712
# AVERAGE VAL LOSS: 0.21533982455730438
# #################
# # EPOCH 510
# #################
# AVERAGE TRAIN LOSS: 0.06071806699037552
# AVERAGE VAL LOSS: 0.2375895231962204
# #################
# # EPOCH 511
# #################
# AVERAGE TRAIN LOSS: 0.06601638346910477
# AVERAGE VAL LOSS: 0.2818729281425476
# #################
# # EPOCH 512
# #################
# AVERAGE TRAIN LOSS: 0.08480025082826614
# AVERAGE VAL LOSS: 0.23365426063537598
# #################
# # EPOCH 513
# #################
# AVERAGE TRAIN LOSS: 0.0689353197813034
# AVERAGE VAL LOSS: 0.24139507114887238
# #################
# # EPOCH 514
# #################
# AVERAGE TRAIN LOSS: 0.06493760645389557
# AVERAGE VAL LOSS: 0.2412928342819214
# #################
# # EPOCH 515
# #################
# AVERAGE TRAIN LOSS: 0.06555496156215668
# AVERAGE VAL LOSS: 0.27229124307632446
# #################
# # EPOCH 516
# #################
# AVERAGE TRAIN LOSS: 0.06720761209726334
# AVERAGE VAL LOSS: 0.22475937008857727
# #################
# # EPOCH 517
# #################
# AVERAGE TRAIN LOSS: 0.06442318111658096
# AVERAGE VAL LOSS: 0.21611373126506805
# #################
# # EPOCH 518
# #################
# AVERAGE TRAIN LOSS: 0.05518387630581856
# AVERAGE VAL LOSS: 0.21856284141540527
# #################
# # EPOCH 519
# #################
# AVERAGE TRAIN LOSS: 0.05855492502450943
# AVERAGE VAL LOSS: 0.20955340564250946
# #################
# # EPOCH 520
# #################
# AVERAGE TRAIN LOSS: 0.06227966398000717
# AVERAGE VAL LOSS: 0.2240503877401352
# #################
# # EPOCH 521
# #################
# AVERAGE TRAIN LOSS: 0.06577275693416595
# AVERAGE VAL LOSS: 0.2310459017753601
# #################
# # EPOCH 522
# #################
# AVERAGE TRAIN LOSS: 0.06821181625127792
# AVERAGE VAL LOSS: 0.25787246227264404
# #################
# # EPOCH 523
# #################
# AVERAGE TRAIN LOSS: 0.088567815721035
# AVERAGE VAL LOSS: 0.24443480372428894
# #################
# # EPOCH 524
# #################
# AVERAGE TRAIN LOSS: 0.07942137122154236
# AVERAGE VAL LOSS: 0.24491912126541138
# #################
# # EPOCH 525
# #################
# AVERAGE TRAIN LOSS: 0.0740443617105484
# AVERAGE VAL LOSS: 0.2576998174190521
# #################
# # EPOCH 526
# #################
# AVERAGE TRAIN LOSS: 0.06507453322410583
# AVERAGE VAL LOSS: 0.28068214654922485
# #################
# # EPOCH 527
# #################
# AVERAGE TRAIN LOSS: 0.06282070279121399
# AVERAGE VAL LOSS: 0.24307462573051453
# #################
# # EPOCH 528
# #################
# AVERAGE TRAIN LOSS: 0.05643675476312637
# AVERAGE VAL LOSS: 0.21320465207099915
# #################
# # EPOCH 529
# #################
# AVERAGE TRAIN LOSS: 0.05219103768467903
# AVERAGE VAL LOSS: 0.21966296434402466
# #################
# # EPOCH 530
# #################
# AVERAGE TRAIN LOSS: 0.05481700971722603
# AVERAGE VAL LOSS: 0.22265468537807465
# #################
# # EPOCH 531
# #################
# AVERAGE TRAIN LOSS: 0.06086965277791023
# AVERAGE VAL LOSS: 0.2316097468137741
# #################
# # EPOCH 532
# #################
# AVERAGE TRAIN LOSS: 0.05488421395421028
# AVERAGE VAL LOSS: 0.23965668678283691
# #################
# # EPOCH 533
# #################
# AVERAGE TRAIN LOSS: 0.05426078289747238
# AVERAGE VAL LOSS: 0.21285557746887207
# #################
# # EPOCH 534
# #################
# AVERAGE TRAIN LOSS: 0.052516866475343704
# AVERAGE VAL LOSS: 0.21778517961502075
# #################
# # EPOCH 535
# #################
# AVERAGE TRAIN LOSS: 0.051266930997371674
# AVERAGE VAL LOSS: 0.2196279913187027
# #################
# # EPOCH 536
# #################
# AVERAGE TRAIN LOSS: 0.05262256786227226
# AVERAGE VAL LOSS: 0.21567752957344055
# #################
# # EPOCH 537
# #################
# AVERAGE TRAIN LOSS: 0.05155511945486069
# AVERAGE VAL LOSS: 0.21172679960727692
# #################
# # EPOCH 538
# #################
# AVERAGE TRAIN LOSS: 0.052179791033267975
# AVERAGE VAL LOSS: 0.2303723841905594
# #################
# # EPOCH 539
# #################
# AVERAGE TRAIN LOSS: 0.057776253670454025
# AVERAGE VAL LOSS: 0.20189817249774933
# #################
# # EPOCH 540
# #################
# AVERAGE TRAIN LOSS: 0.05496055632829666
# AVERAGE VAL LOSS: 0.21130415797233582
# #################
# # EPOCH 541
# #################
# AVERAGE TRAIN LOSS: 0.05174856260418892
# AVERAGE VAL LOSS: 0.21500548720359802
# #################
# # EPOCH 542
# #################
# AVERAGE TRAIN LOSS: 0.0540962740778923
# AVERAGE VAL LOSS: 0.2015887349843979
# #################
# # EPOCH 543
# #################
# AVERAGE TRAIN LOSS: 0.05005805566906929
# AVERAGE VAL LOSS: 0.21176692843437195
# #################
# # EPOCH 544
# #################
# AVERAGE TRAIN LOSS: 0.05252964049577713
# AVERAGE VAL LOSS: 0.21489374339580536
# #################
# # EPOCH 545
# #################
# AVERAGE TRAIN LOSS: 0.051541101187467575
# AVERAGE VAL LOSS: 0.20765410363674164
# #################
# # EPOCH 546
# #################
# AVERAGE TRAIN LOSS: 0.05624144524335861
# AVERAGE VAL LOSS: 0.26787349581718445
# #################
# # EPOCH 547
# #################
# AVERAGE TRAIN LOSS: 0.06309014558792114
# AVERAGE VAL LOSS: 0.21308180689811707
# #################
# # EPOCH 548
# #################
# AVERAGE TRAIN LOSS: 0.05758938193321228
# AVERAGE VAL LOSS: 0.2262379378080368
# #################
# # EPOCH 549
# #################
# AVERAGE TRAIN LOSS: 0.06201104074716568
# AVERAGE VAL LOSS: 0.23005220293998718
# #################
# # EPOCH 550
# #################
# AVERAGE TRAIN LOSS: 0.0661747008562088
# AVERAGE VAL LOSS: 0.24518005549907684
# #################
# # EPOCH 551
# #################
# AVERAGE TRAIN LOSS: 0.058574240654706955
# AVERAGE VAL LOSS: 0.246194526553154
# #################
# # EPOCH 552
# #################
# AVERAGE TRAIN LOSS: 0.06019855663180351
# AVERAGE VAL LOSS: 0.22539576888084412
# #################
# # EPOCH 553
# #################
# AVERAGE TRAIN LOSS: 0.06285880506038666
# AVERAGE VAL LOSS: 0.21200887858867645
# #################
# # EPOCH 554
# #################
# AVERAGE TRAIN LOSS: 0.062356896698474884
# AVERAGE VAL LOSS: 0.23839214444160461
# #################
# # EPOCH 555
# #################
# AVERAGE TRAIN LOSS: 0.05902940034866333
# AVERAGE VAL LOSS: 0.2698785364627838
# #################
# # EPOCH 556
# #################
# AVERAGE TRAIN LOSS: 0.0601644441485405
# AVERAGE VAL LOSS: 0.2144707441329956
# #################
# # EPOCH 557
# #################
# AVERAGE TRAIN LOSS: 0.05477328225970268
# AVERAGE VAL LOSS: 0.2069832980632782
# #################
# # EPOCH 558
# #################
# AVERAGE TRAIN LOSS: 0.05084042623639107
# AVERAGE VAL LOSS: 0.21548022329807281
# #################
# # EPOCH 559
# #################
# AVERAGE TRAIN LOSS: 0.0496356263756752
# AVERAGE VAL LOSS: 0.2315727025270462
# #################
# # EPOCH 560
# #################
# AVERAGE TRAIN LOSS: 0.049924660474061966
# AVERAGE VAL LOSS: 0.2034897804260254
# #################
# # EPOCH 561
# #################
# AVERAGE TRAIN LOSS: 0.05193774774670601
# AVERAGE VAL LOSS: 0.20977655053138733
# #################
# # EPOCH 562
# #################
# AVERAGE TRAIN LOSS: 0.04944989085197449
# AVERAGE VAL LOSS: 0.2115422636270523
# #################
# # EPOCH 563
# #################
# AVERAGE TRAIN LOSS: 0.04973909258842468
# AVERAGE VAL LOSS: 0.21700820326805115
# #################
# # EPOCH 564
# #################
# AVERAGE TRAIN LOSS: 0.04972272366285324
# AVERAGE VAL LOSS: 0.22041526436805725
# #################
# # EPOCH 565
# #################
# AVERAGE TRAIN LOSS: 0.05910515785217285
# AVERAGE VAL LOSS: 0.21191544830799103
# #################
# # EPOCH 566
# #################
# AVERAGE TRAIN LOSS: 0.05384371802210808
# AVERAGE VAL LOSS: 0.2375134825706482
# #################
# # EPOCH 567
# #################
# AVERAGE TRAIN LOSS: 0.05419163778424263
# AVERAGE VAL LOSS: 0.24166445434093475
# #################
# # EPOCH 568
# #################
# AVERAGE TRAIN LOSS: 0.05733723193407059
# AVERAGE VAL LOSS: 0.2080221325159073
# #################
# # EPOCH 569
# #################
# AVERAGE TRAIN LOSS: 0.05088257044553757
# AVERAGE VAL LOSS: 0.22245056927204132
# #################
# # EPOCH 570
# #################
# AVERAGE TRAIN LOSS: 0.052444446831941605
# AVERAGE VAL LOSS: 0.22381740808486938
# #################
# # EPOCH 571
# #################
# AVERAGE TRAIN LOSS: 0.051180340349674225
# AVERAGE VAL LOSS: 0.21292322874069214
# #################
# # EPOCH 572
# #################
# AVERAGE TRAIN LOSS: 0.04826592653989792
# AVERAGE VAL LOSS: 0.22507739067077637
# #################
# # EPOCH 573
# #################
# AVERAGE TRAIN LOSS: 0.05134807899594307
# AVERAGE VAL LOSS: 0.2214275747537613
# #################
# # EPOCH 574
# #################
# AVERAGE TRAIN LOSS: 0.05197785049676895
# AVERAGE VAL LOSS: 0.2125159054994583
# #################
# # EPOCH 575
# #################
# AVERAGE TRAIN LOSS: 0.0490138903260231
# AVERAGE VAL LOSS: 0.2356252819299698
# #################
# # EPOCH 576
# #################
# AVERAGE TRAIN LOSS: 0.061446450650691986
# AVERAGE VAL LOSS: 0.2241497039794922
# #################
# # EPOCH 577
# #################
# AVERAGE TRAIN LOSS: 0.046610113233327866
# AVERAGE VAL LOSS: 0.21117690205574036
# #################
# # EPOCH 578
# #################
# AVERAGE TRAIN LOSS: 0.044216446578502655
# AVERAGE VAL LOSS: 0.2096164971590042
# #################
# # EPOCH 579
# #################
# AVERAGE TRAIN LOSS: 0.04893866553902626
# AVERAGE VAL LOSS: 0.2232915759086609
# #################
# # EPOCH 580
# #################
# AVERAGE TRAIN LOSS: 0.04876623675227165
# AVERAGE VAL LOSS: 0.22444745898246765
# #################
# # EPOCH 581
# #################
# AVERAGE TRAIN LOSS: 0.05203690007328987
# AVERAGE VAL LOSS: 0.2284480631351471
# #################
# # EPOCH 582
# #################
# AVERAGE TRAIN LOSS: 0.0537116602063179
# AVERAGE VAL LOSS: 0.2300300896167755
# #################
# # EPOCH 583
# #################
# AVERAGE TRAIN LOSS: 0.04891040176153183
# AVERAGE VAL LOSS: 0.22312194108963013
# #################
# # EPOCH 584
# #################
# AVERAGE TRAIN LOSS: 0.06118686869740486
# AVERAGE VAL LOSS: 0.21188947558403015
# #################
# # EPOCH 585
# #################
# AVERAGE TRAIN LOSS: 0.04975641146302223
# AVERAGE VAL LOSS: 0.2204238474369049
# #################
# # EPOCH 586
# #################
# AVERAGE TRAIN LOSS: 0.044804029166698456
# AVERAGE VAL LOSS: 0.2260480672121048
# #################
# # EPOCH 587
# #################
# AVERAGE TRAIN LOSS: 0.04718092828989029
# AVERAGE VAL LOSS: 0.24949274957180023
# #################
# # EPOCH 588
# #################
# AVERAGE TRAIN LOSS: 0.05224510282278061
# AVERAGE VAL LOSS: 0.22557704150676727
# #################
# # EPOCH 589
# #################
# AVERAGE TRAIN LOSS: 0.05630512163043022
# AVERAGE VAL LOSS: 0.2179490178823471
# #################
# # EPOCH 590
# #################
# AVERAGE TRAIN LOSS: 0.060608066618442535
# AVERAGE VAL LOSS: 0.2687686085700989
# #################
# # EPOCH 591
# #################
# AVERAGE TRAIN LOSS: 0.08240827172994614
# AVERAGE VAL LOSS: 0.22945478558540344
# #################
# # EPOCH 592
# #################
# AVERAGE TRAIN LOSS: 0.06313177198171616
# AVERAGE VAL LOSS: 0.2523544728755951
# #################
# # EPOCH 593
# #################
# AVERAGE TRAIN LOSS: 0.0670299082994461
# AVERAGE VAL LOSS: 0.277071475982666
# #################
# # EPOCH 594
# #################
# AVERAGE TRAIN LOSS: 0.06692248582839966
# AVERAGE VAL LOSS: 0.21612876653671265
# #################
# # EPOCH 595
# #################
# AVERAGE TRAIN LOSS: 0.05286559462547302
# AVERAGE VAL LOSS: 0.2280464470386505
# #################
# # EPOCH 596
# #################
# AVERAGE TRAIN LOSS: 0.049991823732852936
# AVERAGE VAL LOSS: 0.24771563708782196
# #################
# # EPOCH 597
# #################
# AVERAGE TRAIN LOSS: 0.0453331358730793
# AVERAGE VAL LOSS: 0.2286081314086914
# #################
# # EPOCH 598
# #################
# AVERAGE TRAIN LOSS: 0.04459812492132187
# AVERAGE VAL LOSS: 0.24623070657253265
# #################
# # EPOCH 599
# #################
# AVERAGE TRAIN LOSS: 0.052742987871170044
# AVERAGE VAL LOSS: 0.21904973685741425

# %% [markdown]
# Plot losses

# %%
# Plot losses
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(val_loss_log, label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Final test

# %% [markdown]
# Iterate the dataloader a single time and save all the outputs (in case you have multiple batches)

# %%
all_inputs = []
all_outputs = []
all_labels = []
net.eval() # Evaluation mode (e.g. disable dropout)
with torch.no_grad(): # Disable gradient tracking
    for sample_batched in test_dataloader:
        # Move data to device
        x_batch = sample_batched[0].to(device)
        label_batch = sample_batched[1].to(device)
        # Forward pass
        out = net(x_batch)
        # Save outputs and labels
        all_inputs.append(x_batch)
        all_outputs.append(out)
        all_labels.append(label_batch)
# Concatenate all the outputs and labels ina single tensor
all_inputs  = torch.cat(all_inputs)
all_outputs = torch.cat(all_outputs)
all_labels  = torch.cat(all_labels)

test_loss = loss_fn(all_outputs, all_labels)
print(f"AVERAGE TEST LOSS: {test_loss}")
# Out:
# AVERAGE TEST LOSS: 0.18860073387622833

# %% [markdown]
# In this case the network has a linear output (for a better stability of the loss function).
# To have probability estimates you can apply a sigmoid to the network output.
#
# Since we just need the most probable class and we have a single output, we can consider the sign of the linear output. Negative output means that the class 0 is the most probable (probability < 50%), otherwise class 1 (probability > 50%).
#
# Essentially this network estimates the probability of the input sample to be of class 1.
#
# > **NOTE**
# >
# > You can (and should, for practice) redefine the problem by defining a network with more than one output, each of them corresponding to a specific class (2 in this case). Since the two classes are mutually exclusive, the loss function should be a CrossEntropyLoss (softmax activation). In a multi-class scenario, a BCE loss is suitable when the classes are NOT mutually exclusive.

# %% [markdown]
# ---
#
#
# Get the most probable class inferred by the network

# %%
# Get the most probable class inferred by the network
all_output_classes = torch.zeros(all_outputs.shape).to(device)
all_output_classes[all_outputs > 0] = 1

# %% [markdown]
# Evaluate the test accuracy

# %%
tot_correct_out = (all_output_classes == all_labels).sum()
test_accuracy = 100 * tot_correct_out / len(all_labels)
print(f"TEST ACCURACY: {test_accuracy:.2f}%")
# Out:
# TEST ACCURACY: 94.00%

# %% [markdown]
# Plot the results

# %%
### Plot
x1 = all_inputs.squeeze().cpu().numpy()[:, 0]
x2 = all_inputs.squeeze().cpu().numpy()[:, 1]
y_true = all_labels.squeeze().cpu().numpy()
y_pred = all_output_classes.squeeze().cpu().numpy()

fig, ax = plt.subplots(figsize=(12,8))
# Plot predictions
ax.scatter(x1, x2, c=y_pred, s=1, marker='o')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_title('Network Predictions')
# Mark wrong outputs
error_mask = y_pred != y_true
ax.scatter(x1[error_mask], x2[error_mask], color='red', s=30, marker='x', label='MISCLASSIFIED SAMPLES')
plt.legend()
fig.show()
# Out:
# C:\Users\stefano\.conda\envs\gputest\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
